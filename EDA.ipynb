# %% [markdown]
# **EDA for Mod 2 Project**

# %% [markdown]
# # Imports

# %%
import pandas as pd
pd.set_option('display.max_columns', None)

import numpy as np

import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns

import json
import os
import gmaps 
import gmaps.datasets 
import gmaps.geojson_geometries

# %% [markdown]
# # Read in Data

# %%
df = pd.read_csv('datasets/kc_house_data.csv')

# %% [markdown]
# # EDA

# %% [markdown]
# ## Initial Review

# %% [markdown]
# **Data Summary**
# * 21 columns
# * 21597 rows
# * columns that contain NaN
#     * waterfront
#     * view
#     * yr_renovated
# * columns with object data that should be another type
#     * date - convert to datetime
#     * sqft_basement - convert to numeric

# %%
df.head()
# Out:
#            id        date     price  bedrooms  bathrooms  sqft_living  \
# 0  7129300520  10/13/2014  221900.0         3       1.00         1180
# 1  6414100192   12/9/2014  538000.0         3       2.25         2570
# 2  5631500400   2/25/2015  180000.0         2       1.00          770
# 3  2487200875   12/9/2014  604000.0         4       3.00         1960
# 4  1954400510   2/18/2015  510000.0         3       2.00         1680
#
#    sqft_lot  floors  waterfront  view  condition  grade  sqft_above  \
# 0      5650     1.0         NaN   0.0          3      7        1180
# 1      7242     2.0         0.0   0.0          3      7        2170
# 2     10000     1.0         0.0   0.0          3      6         770
# 3      5000     1.0         0.0   0.0          5      7        1050
# 4      8080     1.0         0.0   0.0          3      8        1680
#
#   sqft_basement  yr_built  yr_renovated  zipcode      lat     long  \
# 0           0.0      1955           0.0    98178  47.5112 -122.257
# 1         400.0      1951        1991.0    98125  47.7210 -122.319
# 2           0.0      1933           NaN    98028  47.7379 -122.233
# 3         910.0      1965           0.0    98136  47.5208 -122.393
# 4           0.0      1987           0.0    98074  47.6168 -122.045
#
#    sqft_living15  sqft_lot15
# 0           1340        5650
# 1           1690        7639
# 2           2720        8062
# 3           1360        5000
# 4           1800        7503

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21597 entries, 0 to 21596
# Data columns (total 21 columns):
# id               21597 non-null int64
# date             21597 non-null object
# price            21597 non-null float64
# bedrooms         21597 non-null int64
# bathrooms        21597 non-null float64
# sqft_living      21597 non-null int64
# sqft_lot         21597 non-null int64
# floors           21597 non-null float64
# waterfront       19221 non-null float64
# view             21534 non-null float64
# condition        21597 non-null int64
# grade            21597 non-null int64
# sqft_above       21597 non-null int64
# sqft_basement    21597 non-null object
# yr_built         21597 non-null int64
# yr_renovated     17755 non-null float64
# zipcode          21597 non-null int64
# lat              21597 non-null float64
# long             21597 non-null float64
# sqft_living15    21597 non-null int64
# sqft_lot15       21597 non-null int64
# dtypes: float64(8), int64(11), object(2)
# memory usage: 3.5+ MB

# %%
df.describe()
# Out:
#                  id         price      bedrooms     bathrooms   sqft_living  \
# count  2.159700e+04  2.159700e+04  21597.000000  21597.000000  21597.000000
# mean   4.580474e+09  5.402966e+05      3.373200      2.115826   2080.321850
# std    2.876736e+09  3.673681e+05      0.926299      0.768984    918.106125
# min    1.000102e+06  7.800000e+04      1.000000      0.500000    370.000000
# 25%    2.123049e+09  3.220000e+05      3.000000      1.750000   1430.000000
# 50%    3.904930e+09  4.500000e+05      3.000000      2.250000   1910.000000
# 75%    7.308900e+09  6.450000e+05      4.000000      2.500000   2550.000000
# max    9.900000e+09  7.700000e+06     33.000000      8.000000  13540.000000
#
#            sqft_lot        floors    waterfront          view     condition  \
# count  2.159700e+04  21597.000000  19221.000000  21534.000000  21597.000000
# mean   1.509941e+04      1.494096      0.007596      0.233863      3.409825
# std    4.141264e+04      0.539683      0.086825      0.765686      0.650546
# min    5.200000e+02      1.000000      0.000000      0.000000      1.000000
# 25%    5.040000e+03      1.000000      0.000000      0.000000      3.000000
# 50%    7.618000e+03      1.500000      0.000000      0.000000      3.000000
# 75%    1.068500e+04      2.000000      0.000000      0.000000      4.000000
# max    1.651359e+06      3.500000      1.000000      4.000000      5.000000
#
#               grade    sqft_above      yr_built  yr_renovated       zipcode  \
# count  21597.000000  21597.000000  21597.000000  17755.000000  21597.000000
# mean       7.657915   1788.596842   1970.999676     83.636778  98077.951845
# std        1.173200    827.759761     29.375234    399.946414     53.513072
# min        3.000000    370.000000   1900.000000      0.000000  98001.000000
# 25%        7.000000   1190.000000   1951.000000      0.000000  98033.000000
# 50%        7.000000   1560.000000   1975.000000      0.000000  98065.000000
# 75%        8.000000   2210.000000   1997.000000      0.000000  98118.000000
# max       13.000000   9410.000000   2015.000000   2015.000000  98199.000000
#
#                 lat          long  sqft_living15     sqft_lot15
# count  21597.000000  21597.000000   21597.000000   21597.000000
# mean      47.560093   -122.213982    1986.620318   12758.283512
# std        0.138552      0.140724     685.230472   27274.441950
# min       47.155900   -122.519000     399.000000     651.000000
# 25%       47.471100   -122.328000    1490.000000    5100.000000
# 50%       47.571800   -122.231000    1840.000000    7620.000000
# 75%       47.678000   -122.125000    2360.000000   10083.000000
# max       47.777600   -121.315000    6210.000000  871200.000000

# %% [markdown]
# ## Convert Data Types
#
# Columns identified as needing type conversion
# * date - convert to datetime
# * sqft_basement - convert to numeric

# %% [markdown]
# ### Assign new dataframe variable for the cleaned data

# %%
df_clean = df

# %% [markdown]
# ### sqft_basement
# convert to float

# %%
df_clean.sqft_basement.value_counts()
# Out:
# 0.0       12826
# ?           454
# 600.0       217
# 500.0       209
# 700.0       208
#           ...
# 65.0          1
# 1008.0        1
# 2250.0        1
# 704.0         1
# 906.0         1
# Name: sqft_basement, Length: 304, dtype: int64

# %% [markdown]
# **sqft_basement** contains a ? for 454 rows.
#
# Will convert that to 0 b/c unknown basement should be considered no basement because that is the default, unless new data is received later

# %%
df_clean.loc[df_clean.sqft_basement == '?', 'sqft_basement'] = '0'

# %%
df_clean.sqft_basement = df_clean.sqft_basement.astype(float)

# %% [markdown]
# ### date
# convert to datetime

# %%
df_clean.date = pd.to_datetime(df.date)

# %% [markdown]
# ## Review and deal with NaN type values
#
# columns that contain NaN
# * waterfront
# * view
# * yr_renovated

# %% [markdown]
# ### waterfront

# %%
df_clean.waterfront.describe()
# Out:
# count    19221.000000
# mean         0.007596
# std          0.086825
# min          0.000000
# 25%          0.000000
# 50%          0.000000
# 75%          0.000000
# max          1.000000
# Name: waterfront, dtype: float64

# %% [markdown]
# **waterfront is a binary category, will treat rows with NaN as 0, no view to a waterfront b/c
# it is the more conservative choice**

# %%
df_clean.waterfront.fillna(0.0, inplace=True)

# %% [markdown]
# ### view

# %%
df_clean.view.value_counts(dropna=False)
# Out:
# 0.0    19422
# 2.0      957
# 3.0      508
# 1.0      330
# 4.0      317
# NaN       63
# Name: view, dtype: int64

# %% [markdown]
# The category has valid values of 0,1,2,3,4. presumably the number of times the property has been viewed,
# although it seems strange that the max is 4, so the data likely was transformed into 4 bins
# potentially quartiles.
#
# Since most of the houses have a value of 0.0, I will replace the NaN's with 0.0

# %%
df_clean.view.fillna(0.0, inplace=True)

# %% [markdown]
# ### yr_renovated

# %%
df_clean.yr_renovated.describe()
# Out:
# count    17755.000000
# mean        83.636778
# std        399.946414
# min          0.000000
# 25%          0.000000
# 50%          0.000000
# 75%          0.000000
# max       2015.000000
# Name: yr_renovated, dtype: float64

# %%
df_clean.yr_renovated.value_counts()
# Out:
# 0.0       17011
# 2014.0       73
# 2003.0       31
# 2013.0       31
# 2007.0       30
#           ...
# 1946.0        1
# 1959.0        1
# 1971.0        1
# 1951.0        1
# 1954.0        1
# Name: yr_renovated, Length: 70, dtype: int64

# %% [markdown]
# Besides NaN, most of the data is set to 0.0, which can be taken to mean there is no data on a renovation or
# that the house was never renovated.
#
# The Nan's will be set to 0.0, since that seems to be the default value, and no renovation is
# equivalent to no known renovation.

# %%
df_clean.yr_renovated.fillna(0.0, inplace=True)

# %% [markdown]
# ### Look for strange values

# %%
df.describe()
# Out:
#                  id         price      bedrooms     bathrooms   sqft_living  \
# count  2.159700e+04  2.159700e+04  21597.000000  21597.000000  21597.000000
# mean   4.580474e+09  5.402966e+05      3.373200      2.115826   2080.321850
# std    2.876736e+09  3.673681e+05      0.926299      0.768984    918.106125
# min    1.000102e+06  7.800000e+04      1.000000      0.500000    370.000000
# 25%    2.123049e+09  3.220000e+05      3.000000      1.750000   1430.000000
# 50%    3.904930e+09  4.500000e+05      3.000000      2.250000   1910.000000
# 75%    7.308900e+09  6.450000e+05      4.000000      2.500000   2550.000000
# max    9.900000e+09  7.700000e+06     33.000000      8.000000  13540.000000
#
#            sqft_lot        floors    waterfront          view     condition  \
# count  2.159700e+04  21597.000000  21597.000000  21597.000000  21597.000000
# mean   1.509941e+04      1.494096      0.006760      0.233181      3.409825
# std    4.141264e+04      0.539683      0.081944      0.764673      0.650546
# min    5.200000e+02      1.000000      0.000000      0.000000      1.000000
# 25%    5.040000e+03      1.000000      0.000000      0.000000      3.000000
# 50%    7.618000e+03      1.500000      0.000000      0.000000      3.000000
# 75%    1.068500e+04      2.000000      0.000000      0.000000      4.000000
# max    1.651359e+06      3.500000      1.000000      4.000000      5.000000
#
#               grade    sqft_above  sqft_basement      yr_built  yr_renovated  \
# count  21597.000000  21597.000000   21597.000000  21597.000000  21597.000000
# mean       7.657915   1788.596842     285.716581   1970.999676     68.758207
# std        1.173200    827.759761     439.819830     29.375234    364.037499
# min        3.000000    370.000000       0.000000   1900.000000      0.000000
# 25%        7.000000   1190.000000       0.000000   1951.000000      0.000000
# 50%        7.000000   1560.000000       0.000000   1975.000000      0.000000
# 75%        8.000000   2210.000000     550.000000   1997.000000      0.000000
# max       13.000000   9410.000000    4820.000000   2015.000000   2015.000000
#
#             zipcode           lat          long  sqft_living15     sqft_lot15
# count  21597.000000  21597.000000  21597.000000   21597.000000   21597.000000
# mean   98077.951845     47.560093   -122.213982    1986.620318   12758.283512
# std       53.513072      0.138552      0.140724     685.230472   27274.441950
# min    98001.000000     47.155900   -122.519000     399.000000     651.000000
# 25%    98033.000000     47.471100   -122.328000    1490.000000    5100.000000
# 50%    98065.000000     47.571800   -122.231000    1840.000000    7620.000000
# 75%    98118.000000     47.678000   -122.125000    2360.000000   10083.000000
# max    98199.000000     47.777600   -121.315000    6210.000000  871200.000000

# %% [markdown]
# #### Look at the max values of the data columns

# %%
for col in df_clean.columns:
    print(f'Max for {col}')
    display(df_clean[df_clean[col] == df_clean[col].max()])
# Out:
# Max for id
#                id       date     price  bedrooms  bathrooms  sqft_living  \
# 15937  9900000190 2014-10-30  268950.0         3        1.0         1320
#
#        sqft_lot  floors  waterfront  view  condition  grade  sqft_above  \
# 15937      8100     1.0         0.0   0.0          3      6         880
#
#        sqft_basement  yr_built  yr_renovated  zipcode      lat     long  \
# 15937          440.0      1943           0.0    98166  47.4697 -122.351
#
#        sqft_living15  sqft_lot15
# 15937           1000        8100
# Max for date
#                id       date      price  bedrooms  bathrooms  sqft_living  \
# 16580  9106000005 2015-05-27  1310000.0         4       2.25         3750
#
#        sqft_lot  floors  waterfront  view  condition  grade  sqft_above  \
# 16580      5000     2.0         0.0   0.0          5      8        2440
#
#        sqft_basement  yr_built  yr_renovated  zipcode      lat     long  \
# 16580         1310.0      1924           0.0    98115  47.6747 -122.303
#
#        sqft_living15  sqft_lot15
# 16580           2170        4590
# Max for price
#               id       date      price  bedrooms  bathrooms  sqft_living  \
# 7245  6762700020 2014-10-13  7700000.0         6        8.0        12050
#
#       sqft_lot  floors  waterfront  view  condition  grade  sqft_above  \
# 7245     27600     2.5         0.0   3.0          4     13        8570
#
#       sqft_basement  yr_built  yr_renovated  zipcode      lat     long  \
# 7245         3480.0      1910        1987.0    98102  47.6298 -122.323
#
#       sqft_living15  sqft_lot15
# 7245           3940        8800
# Max for bedrooms
#                id       date     price  bedrooms  bathrooms  sqft_living  \
# 15856  2402100895 2014-06-25  640000.0        33       1.75         1620
#
#        sqft_lot  floors  waterfront  view  condition  grade  sqft_above  \
# 15856      6000     1.0         0.0   0.0          5      7        1040
#
#        sqft_basement  yr_built  yr_renovated  zipcode      lat     long  \
# 15856          580.0      1947           0.0    98103  47.6878 -122.331
#
#        sqft_living15  sqft_lot15
# 15856           1330        4700
# Max for bathrooms
#                id       date      price  bedrooms  bathrooms  sqft_living  \
# 7245   6762700020 2014-10-13  7700000.0         6        8.0        12050
# 12764  1225069038 2014-05-05  2280000.0         7        8.0        13540
#
#        sqft_lot  floors  waterfront  view  condition  grade  sqft_above  \
# 7245      27600     2.5         0.0   3.0          4     13        8570
# 12764    307752     3.0         0.0   4.0          3     12        9410
#
#        sqft_basement  yr_built  yr_renovated  zipcode      lat     long  \
# 7245          3480.0      1910        1987.0    98102  47.6298 -122.323
# 12764         4130.0      1999           0.0    98053  47.6675 -121.986
#
#        sqft_living15  sqft_lot15
# 7245            3940        8800
# 12764           4850      217800
# Max for sqft_living
#                id       date      price  bedrooms  bathrooms  sqft_living  \
# 12764  1225069038 2014-05-05  2280000.0         7        8.0        13540
#
#        sqft_lot  floors  waterfront  view  condition  grade  sqft_above  \
# 12764    307752     3.0         0.0   4.0          3     12        9410
#
#        sqft_basement  yr_built  yr_renovated  zipcode      lat     long  \
# 12764         4130.0      1999           0.0    98053  47.6675 -121.986
#
#        sqft_living15  sqft_lot15
# 12764           4850      217800
# Max for sqft_lot
#               id       date     price  bedrooms  bathrooms  sqft_living  \
# 1717  1020069017 2015-03-27  700000.0         4        1.0         1300
#
#       sqft_lot  floors  waterfront  view  condition  grade  sqft_above  \
# 1717   1651359     1.0         0.0   3.0          4      6        1300
#
#       sqft_basement  yr_built  yr_renovated  zipcode      lat     long  \
# 1717            0.0      1920           0.0    98022  47.2313 -122.023
#
#       sqft_living15  sqft_lot15
# 1717           2560      425581
# Max for floors
#                id       date      price  bedrooms  bathrooms  sqft_living  \
# 10066  1972202010 2014-08-01   435000.0         3       3.00         1440
# 11582  3180100023 2015-01-30   544000.0         3       2.50         1760
# 14871  8673400177 2015-04-02   525000.0         3       3.00         1730
# 15410  1702900664 2015-04-16   479000.0         2       2.50         1730
# 18462  1346300150 2014-10-20  3300000.0         8       4.00         7710
# 20292  1972200426 2014-09-18   525000.0         2       2.75         1310
# 20756  1972200428 2014-06-25   563500.0         3       2.50         1400
#
#        sqft_lot  floors  waterfront  view  condition  grade  sqft_above  \
# 10066      1350     3.5         0.0   2.0          3      8        1440
# 11582      1755     3.5         0.0   0.0          3      8        1760
# 14871      1074     3.5         0.0   0.0          3      8        1730
# 15410      1037     3.5         0.0   0.0          3      8        1730
# 18462     11750     3.5         0.0   0.0          5     12        6090
# 20292      1268     3.5         0.0   0.0          3      8        1310
# 20756      1312     3.5         0.0   0.0          3      8        1400
#
#        sqft_basement  yr_built  yr_renovated  zipcode      lat     long  \
# 10066            0.0      2005           0.0    98103  47.6525 -122.345
# 11582            0.0      1998           0.0    98105  47.6688 -122.279
# 14871            0.0      2006           0.0    98107  47.6692 -122.392
# 15410            0.0      2008           0.0    98118  47.5594 -122.285
# 18462         1620.0      1904           0.0    98112  47.6263 -122.314
# 20292            0.0      2007           0.0    98103  47.6534 -122.355
# 20756            0.0      2007           0.0    98103  47.6534 -122.355
#
#        sqft_living15  sqft_lot15
# 10066           1440        1350
# 11582           1700        1721
# 14871           1370        1185
# 15410           1280        1026
# 18462           4210        8325
# 20292           1350        1288
# 20756           1350        1312
# Max for waterfront
#                id       date      price  bedrooms  bathrooms  sqft_living  \
# 49      822039084 2015-03-11  1350000.0         3       2.50         2753
# 230    8096000060 2015-04-13   655000.0         2       1.75         1450
# 246    2025069065 2014-09-29  2400000.0         4       2.50         3650
# 264    2123039032 2014-10-27   369900.0         1       0.75          760
# 300    3225069065 2014-06-24  3080000.0         4       5.00         4550
# ...           ...        ...        ...       ...        ...          ...
# 19968  2025069140 2015-03-17  1900000.0         3       2.50         2830
# 20309   518500480 2014-08-11  3000000.0         3       3.50         4410
# 20751  8043700105 2015-04-17  2300000.0         4       4.00         4360
# 21185   518500460 2014-10-08  2230000.0         3       3.50         3760
# 21560  9253900271 2015-01-07  3570000.0         5       4.50         4850
#
#        sqft_lot  floors  waterfront  view  condition  grade  sqft_above  \
# 49        65005     1.0         1.0   2.0          5      9        2165
# 230       15798     2.0         1.0   4.0          3      7        1230
# 246        8354     1.0         1.0   4.0          3      9        1830
# 264       10079     1.0         1.0   4.0          5      5         760
# 300       18641     1.0         1.0   4.0          3     10        2600
# ...         ...     ...         ...   ...        ...    ...         ...
# 19968      4334     3.0         1.0   4.0          3     10        2830
# 20309     10756     2.0         1.0   4.0          3     11        3430
# 20751      8175     2.5         1.0   4.0          3     10        3940
# 21185      5634     2.0         1.0   4.0          3     11        2830
# 21560     10584     2.0         1.0   4.0          3     10        3540
#
#        sqft_basement  yr_built  yr_renovated  zipcode      lat     long  \
# 49             588.0      1953           0.0    98070  47.4041 -122.451
# 230            220.0      1915        1978.0    98166  47.4497 -122.375
# 246           1820.0      2000           0.0    98074  47.6338 -122.072
# 264              0.0      1936           0.0    98070  47.4683 -122.438
# 300           1950.0      2002           0.0    98074  47.6053 -122.077
# ...              ...       ...           ...      ...      ...      ...
# 19968            0.0      2006           0.0    98074  47.6318 -122.071
# 20309          980.0      2014           0.0    98056  47.5283 -122.205
# 20751          420.0      2007           0.0    98008  47.5724 -122.104
# 21185          930.0      2014           0.0    98056  47.5285 -122.205
# 21560         1310.0      2007           0.0    98008  47.5943 -122.110
#
#        sqft_living15  sqft_lot15
# 49              2680       72513
# 230             2030       13193
# 246             3120       18841
# 264             1230       14267
# 300             4550       19508
# ...              ...         ...
# 19968           2830       38211
# 20309           3550        5634
# 20751           2670        8525
# 21185           3560        5762
# 21560           3470       18270
#
# [146 rows x 21 columns]
# Max for view
#                id       date      price  bedrooms  bathrooms  sqft_living  \
# 21     2524049179 2014-08-26  2000000.0         3       2.75         3050
# 58     7922800400 2014-08-27   951000.0         5       3.25         3250
# 230    8096000060 2015-04-13   655000.0         2       1.75         1450
# 246    2025069065 2014-09-29  2400000.0         4       2.50         3650
# 264    2123039032 2014-10-27   369900.0         1       0.75          760
# ...           ...        ...        ...       ...        ...          ...
# 20751  8043700105 2015-04-17  2300000.0         4       4.00         4360
# 20907  7852070210 2014-05-27  1150000.0         4       3.00         5940
# 21034  2424059170 2015-02-19   900000.0         5       6.00         7120
# 21185   518500460 2014-10-08  2230000.0         3       3.50         3760
# 21560  9253900271 2015-01-07  3570000.0         5       4.50         4850
#
#        sqft_lot  floors  waterfront  view  condition  grade  sqft_above  \
# 21        44867     1.0         0.0   4.0          3      9        2330
# 58        14342     2.0         0.0   4.0          4      8        3250
# 230       15798     2.0         1.0   4.0          3      7        1230
# 246        8354     1.0         1.0   4.0          3      9        1830
# 264       10079     1.0         1.0   4.0          5      5         760
# ...         ...     ...         ...   ...        ...    ...         ...
# 20751      8175     2.5         1.0   4.0          3     10        3940
# 20907     11533     2.0         0.0   4.0          3     11        4950
# 21034     40806     2.0         0.0   4.0          3     12        5480
# 21185      5634     2.0         1.0   4.0          3     11        2830
# 21560     10584     2.0         1.0   4.0          3     10        3540
#
#        sqft_basement  yr_built  yr_renovated  zipcode      lat     long  \
# 21             720.0      1968           0.0    98040  47.5316 -122.233
# 58               0.0      1968           0.0    98008  47.5880 -122.116
# 230            220.0      1915        1978.0    98166  47.4497 -122.375
# 246           1820.0      2000           0.0    98074  47.6338 -122.072
# 264              0.0      1936           0.0    98070  47.4683 -122.438
# ...              ...       ...           ...      ...      ...      ...
# 20751          420.0      2007           0.0    98008  47.5724 -122.104
# 20907          990.0      2004           0.0    98065  47.5443 -121.870
# 21034         1640.0      2007           0.0    98006  47.5451 -122.114
# 21185          930.0      2014           0.0    98056  47.5285 -122.205
# 21560         1310.0      2007           0.0    98008  47.5943 -122.110
#
#        sqft_living15  sqft_lot15
# 21              4110       20336
# 58              2960       11044
# 230             2030       13193
# 246             3120       18841
# 264             1230       14267
# ...              ...         ...
# 20751           2670        8525
# 20907           4240       12813
# 21034           3440       36859
# 21185           3560        5762
# 21560           3470       18270
#
# [317 rows x 21 columns]
# Max for condition
#                id       date      price  bedrooms  bathrooms  sqft_living  \
# 3      2487200875 2014-12-09   604000.0         4       3.00         1960
# 25     1202000200 2014-11-03   233000.0         3       2.00         1710
# 27     3303700376 2014-12-01   667000.0         3       1.00         1400
# 49      822039084 2015-03-11  1350000.0         3       2.50         2753
# 62     5072410070 2014-10-21   505000.0         3       1.75         2519
# ...           ...        ...        ...       ...        ...          ...
# 19588  7518504130 2014-06-26   663000.0         3       2.00         1480
# 19604  3902100175 2014-07-28   850000.0         5       3.00         3900
# 19857  3449000060 2014-10-01   320000.0         3       1.00         1400
# 19889  2888000030 2014-09-26   500000.0         4       2.25         2270
# 21287   522059130 2015-04-29   465000.0         3       1.00         1150
#
#        sqft_lot  floors  waterfront  view  condition  grade  sqft_above  \
# 3          5000     1.0         0.0   0.0          5      7        1050
# 25         4697     1.5         0.0   0.0          5      6        1710
# 27         1581     1.5         0.0   0.0          5      8        1400
# 49        65005     1.0         1.0   2.0          5      9        2165
# 62         8690     2.0         0.0   0.0          5      8        2519
# ...         ...     ...         ...   ...        ...    ...         ...
# 19588      3876     1.0         0.0   0.0          5      7         860
# 19604      5250     1.5         0.0   1.0          5      8        2620
# 19857      9000     1.0         0.0   0.0          5      7        1400
# 19889      8196     1.0         0.0   0.0          5      7        1150
# 21287     18200     1.0         0.0   0.0          5      7        1150
#
#        sqft_basement  yr_built  yr_renovated  zipcode      lat     long  \
# 3              910.0      1965           0.0    98136  47.5208 -122.393
# 25               0.0      1941           0.0    98002  47.3048 -122.218
# 27               0.0      1909           0.0    98112  47.6221 -122.314
# 49             588.0      1953           0.0    98070  47.4041 -122.451
# 62               0.0      1973           0.0    98166  47.4428 -122.344
# ...              ...       ...           ...      ...      ...      ...
# 19588          620.0      1928           0.0    98117  47.6808 -122.382
# 19604         1280.0      1931           0.0    98116  47.5577 -122.389
# 19857            0.0      1959           0.0    98059  47.5022 -122.145
# 19889         1120.0      1963           0.0    98034  47.7214 -122.227
# 21287            0.0      1959           0.0    98058  47.4262 -122.187
#
#        sqft_living15  sqft_lot15
# 3               1360        5000
# 25              1030        4705
# 27              1860        3861
# 49              2680       72513
# 62              2500        9500
# ...              ...         ...
# 19588           1660        3774
# 19604           1950        5700
# 19857           1440        8400
# 19889           1920       10122
# 21287           1714       18200
#
# [1701 rows x 21 columns]
# Max for grade
#                id       date      price  bedrooms  bathrooms  sqft_living  \
# 4407   2470100110 2014-08-04  5570000.0         5       5.75         9200
# 4807   9831200500 2015-03-04  2480000.0         5       3.75         6810
# 5446   7237501190 2014-10-10  1780000.0         4       3.25         4890
# 6035   1725059316 2014-11-20  2390000.0         4       4.00         6330
# 7028    853200010 2014-07-01  3800000.0         5       5.50         7050
# 7245   6762700020 2014-10-13  7700000.0         6       8.00        12050
# 7900   1068000375 2014-09-23  3200000.0         6       5.00         7100
# 9245   9208900037 2014-09-19  6890000.0         6       7.75         9890
# 10362  3303850390 2014-12-12  2980000.0         5       5.50         7400
# 13398  2426039123 2015-01-30  2420000.0         5       4.75         7880
# 13687  4139900180 2015-04-20  2340000.0         4       2.50         4500
# 14542  2303900035 2014-06-11  2890000.0         5       6.25         8670
# 19002  2303900100 2014-09-11  3800000.0         3       4.25         5510
#
#        sqft_lot  floors  waterfront  view  condition  grade  sqft_above  \
# 4407      35069     2.0         0.0   0.0          3     13        6200
# 4807       7500     2.5         0.0   0.0          3     13        6110
# 5446      13402     2.0         0.0   0.0          3     13        4890
# 6035      13296     2.0         0.0   2.0          3     13        4900
# 7028      42840     1.0         0.0   2.0          4     13        4320
# 7245      27600     2.5         0.0   3.0          4     13        8570
# 7900      18200     2.5         0.0   0.0          3     13        5240
# 9245      31374     2.0         0.0   4.0          3     13        8860
# 10362     18898     2.0         0.0   3.0          3     13        6290
# 13398     24250     2.0         0.0   2.0          3     13        7880
# 13687     35200     1.0         0.0   0.0          3     13        4500
# 14542     64033     2.0         0.0   4.0          3     13        6120
# 19002     35000     2.0         0.0   4.0          3     13        4910
#
#        sqft_basement  yr_built  yr_renovated  zipcode      lat     long  \
# 4407          3000.0      2001           0.0    98039  47.6289 -122.233
# 4807           700.0      1922           0.0    98102  47.6285 -122.322
# 5446             0.0      2004           0.0    98059  47.5303 -122.131
# 6035          1430.0      2000           0.0    98033  47.6488 -122.201
# 7028          2730.0      1978           0.0    98004  47.6229 -122.220
# 7245          3480.0      1910        1987.0    98102  47.6298 -122.323
# 7900          1860.0      1933        2002.0    98199  47.6427 -122.408
# 9245          1030.0      2001           0.0    98039  47.6305 -122.240
# 10362         1110.0      2001           0.0    98006  47.5431 -122.112
# 13398            0.0      1996           0.0    98177  47.7334 -122.362
# 13687            0.0      1988           0.0    98006  47.5477 -122.126
# 14542         2550.0      1965           0.0    98177  47.7295 -122.372
# 19002          600.0      1997           0.0    98177  47.7296 -122.370
#
#        sqft_living15  sqft_lot15
# 4407            3560       24345
# 4807            2660        7500
# 5446            5790       13539
# 6035            2200        9196
# 7028            5070       20570
# 7245            3940        8800
# 7900            3130        6477
# 9245            4540       42730
# 10362           6110       26442
# 13398           2740       10761
# 13687           4760       35200
# 14542           4140       81021
# 19002           3430       45302
# Max for sqft_above
#                id       date      price  bedrooms  bathrooms  sqft_living  \
# 12764  1225069038 2014-05-05  2280000.0         7        8.0        13540
#
#        sqft_lot  floors  waterfront  view  condition  grade  sqft_above  \
# 12764    307752     3.0         0.0   4.0          3     12        9410
#
#        sqft_basement  yr_built  yr_renovated  zipcode      lat     long  \
# 12764         4130.0      1999           0.0    98053  47.6675 -121.986
#
#        sqft_living15  sqft_lot15
# 12764           4850      217800
# Max for sqft_basement
#               id       date      price  bedrooms  bathrooms  sqft_living  \
# 8085  1924059029 2014-06-17  4670000.0         5       6.75         9640
#
#       sqft_lot  floors  waterfront  view  condition  grade  sqft_above  \
# 8085     13068     1.0         1.0   4.0          3     12        4820
#
#       sqft_basement  yr_built  yr_renovated  zipcode     lat    long  \
# 8085         4820.0      1983        2009.0    98040  47.557 -122.21
#
#       sqft_living15  sqft_lot15
# 8085           3270       10454
# Max for yr_built
#                id       date      price  bedrooms  bathrooms  sqft_living  \
# 643    9385200045 2015-05-12   729500.0         3       2.50         1660
# 1761   1832100030 2014-06-25   597326.0         4       4.00         3570
# 2685   3076500830 2014-10-29   385195.0         1       1.00          710
# 4150   8077100031 2015-04-22   631000.0         3       2.25         1670
# 7519   9520900210 2014-12-31   614285.0         5       2.75         2730
# 8032   1250200495 2014-06-24   455000.0         2       1.50         1200
# 8418    558100090 2015-03-12   628000.0         5       2.75         2600
# 14202  8156600210 2015-03-26  1290000.0         5       3.50         2980
# 14475  2770601530 2014-08-26   500000.0         2       2.25         1570
# 14911  2770602360 2015-04-21   671000.0         4       2.75         1890
# 17084  9126100346 2014-06-17   350000.0         3       2.00         1380
# 19706  9161100075 2015-03-18   673000.0         4       2.25         2580
# 19789  9126100765 2014-08-01   455000.0         3       1.75         1320
# 19847  2768100510 2015-04-02   649000.0         3       2.00         1530
# 19891  7853440140 2015-04-09   802945.0         5       3.50         4000
# 19929  8011100047 2015-03-06   530000.0         4       2.75         2740
# 19943  7853430690 2015-01-27   572800.0         3       2.50         3310
# 20070  2768100512 2015-04-22   659000.0         2       2.50         1450
# 20235  7853440050 2015-05-05   771005.0         5       4.50         4000
# 20295  7132300525 2015-04-11   500000.0         3       1.75         1530
# 20353  4385700250 2015-04-07  1800000.0         4       3.50         3480
# 20471  9103000455 2015-04-24   920000.0         4       3.25         2190
# 20472  8691440220 2015-02-02  1290000.0         5       4.00         4360
# 20682   255470030 2015-04-29   619990.0         4       2.75         2630
# 20754  9310300160 2014-08-28   357000.0         5       2.50         2990
# 20782   952005863 2015-05-05   643950.0         3       2.25         1760
# 20836  1257201420 2014-07-09   595000.0         4       3.25         3730
# 20865  3052700385 2015-04-14   765000.0         4       2.25         2030
# 20917  2652501565 2015-04-23  1550000.0         3       3.25         3530
# 20947  6058600220 2014-07-31   230000.0         3       1.50         1040
# 21246  5694500840 2014-11-25   559000.0         2       3.00         1650
# 21254  1773100541 2015-04-17   389950.0         3       2.25         1580
# 21300  6600000050 2015-03-10  1700000.0         4       3.50         3950
# 21317  2424059174 2015-05-08  2000000.0         4       3.25         5640
# 21353   923059259 2015-04-01   455950.0         4       2.50         2720
# 21356  6169901185 2014-05-20   490000.0         5       3.50         4460
# 21416  7104100110 2015-05-11   899000.0         4       3.50         2490
# 21485  4233600150 2015-02-03  1150000.0         5       4.25         4010
#
#        sqft_lot  floors  waterfront  view  condition  grade  sqft_above  \
# 643        1091     3.0         0.0   1.0          3      9        1530
# 1761       8250     2.0         0.0   0.0          3     10        2860
# 2685       6000     1.5         0.0   0.0          3      6         710
# 4150       1396     2.0         0.0   0.0          3      9        1250
# 7519       6401     2.0         0.0   0.0          3      8        2730
# 8032       1259     2.0         0.0   0.0          3      8        1000
# 8418       8160     2.0         0.0   0.0          3      8        2600
# 14202      5100     2.0         0.0   0.0          3     10        2370
# 14475      1269     2.0         0.0   0.0          3      9        1280
# 14911      1475     2.0         0.0   0.0          3      9        1200
# 17084      3600     3.0         0.0   0.0          3      8        1380
# 19706      2875     2.0         0.0   0.0          3      9        2580
# 19789      1014     3.0         0.0   0.0          3      9        1320
# 19847      1442     3.0         0.0   0.0          3      9        1530
# 19891      9234     2.0         0.0   0.0          3      9        4000
# 19929      7872     2.0         0.0   0.0          3     10        2740
# 19943      4682     2.0         0.0   0.0          3      9        2380
# 20070      1213     2.0         0.0   0.0          3      9        1110
# 20235      6713     2.0         0.0   0.0          3      9        4000
# 20295       825     3.0         0.0   0.0          3      8        1530
# 20353      4000     2.0         0.0   0.0          3      9        2460
# 20471      4265     2.0         0.0   0.0          3      9        1540
# 20472      8030     2.0         0.0   0.0          3     10        4360
# 20682      4501     2.0         0.0   0.0          3      8        2630
# 20754      9240     2.0         0.0   0.0          3      8        2990
# 20782      2122     3.0         0.0   0.0          3      9        1760
# 20836      4560     2.0         0.0   0.0          3      9        2760
# 20865      2222     2.0         0.0   0.0          3      9        1610
# 20917      4920     2.0         0.0   0.0          3      9        2660
# 20947      1264     2.0         0.0   0.0          3      9         900
# 21246       960     3.0         0.0   0.0          3      8        1350
# 21254       920     3.0         0.0   0.0          3      8        1580
# 21300      6240     2.0         0.0   0.0          3     11        3950
# 21317     35006     2.0         0.0   2.0          3     11        4900
# 21353      5771     2.0         0.0   0.0          3      8        2720
# 21356      2975     3.0         0.0   2.0          3     10        3280
# 21416      5500     2.0         0.0   0.0          3      9        1780
# 21485      8252     2.0         0.0   0.0          3     10        4010
#
#        sqft_basement  yr_built  yr_renovated  zipcode      lat     long  \
# 643            130.0      2015           0.0    98116  47.5818 -122.402
# 1761           710.0      2015           0.0    98040  47.5784 -122.226
# 2685             0.0      2015           0.0    98144  47.5756 -122.316
# 4150           420.0      2015           0.0    98115  47.6814 -122.288
# 7519             0.0      2015           0.0    98072  47.7685 -122.160
# 8032           200.0      2015           0.0    98144  47.6001 -122.298
# 8418             0.0      2015           0.0    98133  47.7348 -122.340
# 14202          610.0      2015           0.0    98115  47.6782 -122.299
# 14475          290.0      2015           0.0    98199  47.6514 -122.385
# 14911          690.0      2015           0.0    98199  47.6472 -122.383
# 17084            0.0      2015           0.0    98122  47.6074 -122.305
# 19706            0.0      2015           0.0    98116  47.5674 -122.392
# 19789            0.0      2015           0.0    98122  47.6047 -122.305
# 19847            0.0      2015           0.0    98107  47.6692 -122.372
# 19891            0.0      2015           0.0    98024  47.5265 -121.887
# 19929            0.0      2015           0.0    98056  47.4954 -122.172
# 19943          930.0      2015           0.0    98065  47.5201 -121.885
# 20070          340.0      2015           0.0    98107  47.6692 -122.372
# 20235            0.0      2015           0.0    98024  47.5254 -121.886
# 20295            0.0      2015           0.0    98144  47.5929 -122.308
# 20353         1020.0      2015           0.0    98112  47.6356 -122.281
# 20471          650.0      2015           0.0    98122  47.6178 -122.290
# 20472            0.0      2015           0.0    98075  47.5923 -121.973
# 20682            0.0      2015           0.0    98028  47.7748 -122.244
# 20754            0.0      2015           0.0    98133  47.7384 -122.348
# 20782            0.0      2015           0.0    98116  47.5633 -122.385
# 20836          970.0      2015           0.0    98103  47.6725 -122.330
# 20865          420.0      2015           0.0    98117  47.6790 -122.375
# 20917          870.0      2015           0.0    98109  47.6410 -122.357
# 20947          140.0      2015           0.0    98144  47.5951 -122.301
# 21246          300.0      2015           0.0    98103  47.6611 -122.346
# 21254            0.0      2015           0.0    98106  47.5578 -122.363
# 21300            0.0      2015           0.0    98112  47.6221 -122.290
# 21317          740.0      2015           0.0    98006  47.5491 -122.104
# 21353            0.0      2015           0.0    98056  47.4917 -122.170
# 21356            0.0      2015           0.0    98119  47.6313 -122.370
# 21416          710.0      2015           0.0    98136  47.5499 -122.393
# 21485            0.0      2015           0.0    98075  47.5974 -122.013
#
#        sqft_living15  sqft_lot15
# 643             1510        1352
# 1761            2230       10000
# 2685            1440        4800
# 4150            1610        5191
# 7519            2520        6126
# 8032            1320        1852
# 8418            1600        8160
# 14202           1780        5100
# 14475           1570        6000
# 14911           1650        1682
# 17084           1480        3600
# 19706           1290        5750
# 19789           1380        1495
# 19847           1620        1456
# 19891           3690        6600
# 19929           1220        6300
# 19943           2660        5166
# 20070           1620        1456
# 20235           3690        6600
# 20295           1580        1915
# 20353           2620        4000
# 20471           1730        4265
# 20472           3570        6185
# 20682           2380        4599
# 20754           1970       18110
# 20782           1420        1618
# 20836           1800        4560
# 20865           1420        2222
# 20917           1900        4200
# 20947           1350        3000
# 21246           1650        3000
# 21254           1250        1150
# 21300           2040        6240
# 21317           4920       35033
# 21353           1940        4184
# 21356           2490        4231
# 21416           1710        5500
# 21485           3370        8252
# Max for yr_renovated
#                id       date      price  bedrooms  bathrooms  sqft_living  \
# 2293   8712100320 2014-07-28   585000.0         5       2.75         2350
# 3153   6821100195 2015-03-31   830000.0         4       3.00         2020
# 4236   6071800100 2015-03-27   815000.0         6       3.00         2860
# 5678   2202500255 2015-03-05   335000.0         3       2.00         1210
# 7090   9141100005 2014-10-28   285000.0         4       3.50         2770
# 7410   8665900328 2015-01-23   459000.0         4       3.00         1900
# 8683   8835401250 2015-05-06  1490000.0         6       2.75         4430
# 11587  7284900030 2014-05-22   850000.0         4       3.25         3090
# 11621   461004730 2015-04-06   717000.0         3       1.00         1150
# 14845  3585900665 2014-06-06   805000.0         5       2.50         4600
# 15673  3585900190 2014-10-06   825000.0         3       2.50         3400
# 16669  5113000420 2015-03-20   420000.0         4       2.75         2400
# 18560  8935100100 2014-07-01   476000.0         4       3.00         2890
# 19429   582000644 2015-05-01   872500.0         4       2.00         1990
#
#        sqft_lot  floors  waterfront  view  condition  grade  sqft_above  \
# 2293       4178     1.5         0.0   0.0          3      8        1520
# 3153       6000     1.0         0.0   0.0          3      8        1220
# 4236      17853     1.0         0.0   0.0          3      8        1430
# 5678       9926     1.0         0.0   0.0          4      7        1210
# 7090      10505     2.0         0.0   0.0          3      8        2770
# 7410       9077     2.0         0.0   0.0          3      7        1900
# 8683       6440     2.0         0.0   3.0          3     10        2680
# 11587      6744     2.0         0.0   4.0          3      9        3090
# 11621      5000     1.0         0.0   0.0          3      8        1150
# 14845     19831     1.0         0.0   3.0          3      9        2300
# 15673     38400     1.0         0.0   4.0          3      8        1870
# 16669     20000     1.0         0.0   0.0          3      8        1170
# 18560      6885     1.0         0.0   0.0          3      7        1590
# 19429      6000     1.0         0.0   0.0          3      9        1260
#
#        sqft_basement  yr_built  yr_renovated  zipcode      lat     long  \
# 2293           830.0      1922        2015.0    98112  47.6388 -122.300
# 3153           800.0      1968        2015.0    98199  47.6563 -122.401
# 4236          1430.0      1962        2015.0    98006  47.5460 -122.175
# 5678             0.0      1954        2015.0    98006  47.5731 -122.135
# 7090             0.0      1940        2015.0    98133  47.7412 -122.355
# 7410             0.0      1954        2015.0    98155  47.7684 -122.304
# 8683          1750.0      1964        2015.0    98118  47.5462 -122.265
# 11587            0.0      1923        2015.0    98177  47.7680 -122.388
# 11621            0.0      1959        2015.0    98117  47.6805 -122.369
# 14845         2300.0      1956        2015.0    98177  47.7608 -122.378
# 15673         1530.0      1955        2015.0    98177  47.7611 -122.372
# 16669         1230.0      1961        2015.0    98058  47.4556 -122.087
# 18560         1300.0      1945        2015.0    98115  47.6763 -122.282
# 19429          730.0      1956        2015.0    98199  47.6515 -122.397
#
#        sqft_living15  sqft_lot15
# 2293            1920        4178
# 3153            1400        6000
# 4236            1920       13452
# 5678            1690        9737
# 7090            1760       10505
# 7410            1900       12868
# 8683            3530        7314
# 11587           2020        6656
# 11621           1160        5000
# 14845           2890       19831
# 15673           3400       24338
# 16669           1690       20000
# 18560           2180        6885
# 19429           1770        6000
# Max for zipcode
#                id       date      price  bedrooms  bathrooms  sqft_living  \
# 91     5036300431 2015-03-11  1100000.0         5       2.75         3520
# 274    4235400186 2014-11-24   331000.0         3       1.75         1080
# 551    1373800295 2014-10-13  1450000.0         3       3.00         4380
# 611    2321300390 2014-11-05   650000.0         3       2.00         1870
# 628    7010700292 2014-10-09   543500.0         3       2.25         1270
# ...           ...        ...        ...       ...        ...          ...
# 21177  2770601912 2015-04-02   570000.0         3       3.25         1550
# 21410  1070000180 2014-10-15  1110000.0         4       3.50         3660
# 21461  7010700308 2014-11-12  1010000.0         4       3.25         3610
# 21486  2770601782 2014-08-01   453000.0         3       2.50         1510
# 21539  6821101731 2014-09-30   549000.0         3       2.25         1230
#
#        sqft_lot  floors  waterfront  view  condition  grade  sqft_above  \
# 91         6353     2.0         0.0   0.0          4     10        3520
# 274        1306     1.0         0.0   0.0          3      7         580
# 551        6320     2.0         0.0   3.0          5     10        3580
# 611        3388     1.0         0.0   0.0          4      8        1230
# 628        2790     1.0         0.0   0.0          3      7         990
# ...         ...     ...         ...   ...        ...    ...         ...
# 21177      1280     2.0         0.0   0.0          3      9        1220
# 21410      4760     2.0         0.0   0.0          3      9        2840
# 21461      4000     2.0         0.0   0.0          3      9        2640
# 21486      1618     2.5         0.0   0.0          3      8        1330
# 21539      1380     3.0         0.0   0.0          3      8        1230
#
#        sqft_basement  yr_built  yr_renovated  zipcode      lat     long  \
# 91               0.0      2001           0.0    98199  47.6506 -122.391
# 274            500.0      1954        2003.0    98199  47.6601 -122.400
# 551            800.0      1952           0.0    98199  47.6452 -122.411
# 611            640.0      1925           0.0    98199  47.6372 -122.395
# 628            280.0      1970           0.0    98199  47.6581 -122.396
# ...              ...       ...           ...      ...      ...      ...
# 21177          330.0      2013           0.0    98199  47.6493 -122.384
# 21410          820.0      2014           0.0    98199  47.6482 -122.409
# 21461          970.0      2007           0.0    98199  47.6580 -122.396
# 21486          180.0      2011           0.0    98199  47.6515 -122.384
# 21539            0.0      2013           0.0    98199  47.6521 -122.400
#
#        sqft_living15  sqft_lot15
# 91              2520        6250
# 274             1440        2225
# 551             3080        7680
# 611             1780        4050
# 628             1920        4000
# ...              ...         ...
# 21177           1550        1579
# 21410           3210        4640
# 21461           1980        4000
# 21486           1350        1397
# 21539           1760        5664
#
# [317 rows x 21 columns]
# Max for lat
#                id       date     price  bedrooms  bathrooms  sqft_living  \
# 306    7280300196 2015-04-03  550000.0         4       2.75         1800
# 15752  2644300005 2015-04-12  407500.0         4       2.50         1900
# 17450  5500200010 2014-10-14  389950.0         3       1.75         1580
#
#        sqft_lot  floors  waterfront  view  condition  grade  sqft_above  \
# 306        7750     1.0         0.0   0.0          4      8        1400
# 15752      9075     2.0         0.0   0.0          3      7        1900
# 17450      9049     1.0         0.0   0.0          3      8        1580
#
#        sqft_basement  yr_built  yr_renovated  zipcode      lat     long  \
# 306            400.0      1965           0.0    98177  47.7776 -122.384
# 15752            0.0      1988           0.0    98133  47.7776 -122.352
# 17450            0.0      1966           0.0    98177  47.7776 -122.375
#
#        sqft_living15  sqft_lot15
# 306             1800        8275
# 15752           1800        8460
# 17450           2100        8446
# Max for long
#               id       date     price  bedrooms  bathrooms  sqft_living  \
# 2925  8649401270 2015-04-30  167000.0         1       1.00          780
# 4199  1437500015 2014-07-09  150000.0         3       0.75          490
#
#       sqft_lot  floors  waterfront  view  condition  grade  sqft_above  \
# 2925     10235     1.5         0.0   0.0          3      6         780
# 4199     38500     1.5         0.0   0.0          4      5         490
#
#       sqft_basement  yr_built  yr_renovated  zipcode      lat     long  \
# 2925            0.0      1989           0.0    98014  47.7130 -121.315
# 4199            0.0      1959           0.0    98014  47.7112 -121.315
#
#       sqft_living15  sqft_lot15
# 2925            930       10165
# 4199            800       18297
# Max for sqft_living15
#                id       date      price  bedrooms  bathrooms  sqft_living  \
# 19842  2524069078 2015-01-22  2700000.0         4        4.0         7850
#
#        sqft_lot  floors  waterfront  view  condition  grade  sqft_above  \
# 19842     89651     2.0         0.0   0.0          3     12        7850
#
#        sqft_basement  yr_built  yr_renovated  zipcode      lat     long  \
# 19842            0.0      2006           0.0    98027  47.5406 -121.982
#
#        sqft_living15  sqft_lot15
# 19842           6210       95832
# Max for sqft_lot15
#              id       date     price  bedrooms  bathrooms  sqft_living  \
# 9705  225079036 2015-01-07  937500.0         4        4.0         5545
#
#       sqft_lot  floors  waterfront  view  condition  grade  sqft_above  \
# 9705    871200     2.0         0.0   0.0          3     11        3605
#
#       sqft_basement  yr_built  yr_renovated  zipcode     lat     long  \
# 9705         1940.0      2003           0.0    98014  47.676 -121.882
#
#       sqft_living15  sqft_lot15
# 9705           3420      871200

# %% [markdown]
# Potential bad data
# * bedrooms 33, the house is too small for that many bedrooms and only has 1.75 bathrooms
# * sqft_lot 1,651,359, 4x bigger than the 15 surrounding lots.  Requires more investigation

# %% [markdown]
# #### Look at the min values of each column

# %%
for col in df_clean.columns:
    print(f'Min for {col}')
    display(df_clean[df_clean[col] == df_clean[col].min()])
# Out:
# Min for id
#            id       date     price  bedrooms  bathrooms  sqft_living  \
# 2494  1000102 2014-09-16  280000.0         6        3.0         2400
# 2495  1000102 2015-04-22  300000.0         6        3.0         2400
#
#       sqft_lot  floors  waterfront  view  condition  grade  sqft_above  \
# 2494      9373     2.0         0.0   0.0          3      7        2400
# 2495      9373     2.0         0.0   0.0          3      7        2400
#
#       sqft_basement  yr_built  yr_renovated  zipcode      lat     long  \
# 2494            0.0      1991           0.0    98002  47.3262 -122.214
# 2495            0.0      1991           0.0    98002  47.3262 -122.214
#
#       sqft_living15  sqft_lot15
# 2494           2060        7316
# 2495           2060        7316
# Min for date
#                id       date      price  bedrooms  bathrooms  sqft_living  \
# 172    1999700045 2014-05-02   313000.0         3       1.50         1340
# 312    1860600135 2014-05-02  2380000.0         5       2.50         3650
# 502    5467900070 2014-05-02   342000.0         3       2.00         1930
# 775    4040800810 2014-05-02   420000.0         3       2.25         2000
# 1040   7197300105 2014-05-02   550000.0         4       2.50         1940
# ...           ...        ...        ...       ...        ...          ...
# 20543  3438501320 2014-05-02   295000.0         2       2.50         1630
# 20586  7853361370 2014-05-02   555000.0         4       2.50         3310
# 21145  8564860280 2014-05-02   459990.0         3       2.50         2680
# 21271   123059127 2014-05-02   625000.0         4       3.25         2730
# 21374  3832050580 2014-05-02   300000.0         3       2.50         2540
#
#        sqft_lot  floors  waterfront  view  condition  grade  sqft_above  \
# 172        7912     1.5         0.0   0.0          3      7        1340
# 312        9050     2.0         0.0   4.0          5     10        3370
# 502       11947     1.0         0.0   0.0          4      8        1930
# 775        8030     1.0         0.0   0.0          4      8        1000
# 1040      10500     1.0         0.0   0.0          4      7        1140
# ...         ...     ...         ...   ...        ...    ...         ...
# 20543      1368     2.0         0.0   0.0          3      7        1280
# 20586      6500     2.0         0.0   0.0          3      8        3310
# 21145      5539     2.0         0.0   0.0          3      8        2680
# 21271     54014     1.0         0.0   0.0          3      9        1560
# 21374      5050     2.0         0.0   0.0          3      7        2540
#
#        sqft_basement  yr_built  yr_renovated  zipcode      lat     long  \
# 172              0.0      1955           0.0    98133  47.7658 -122.339
# 312            280.0      1921           0.0    98119  47.6345 -122.367
# 502              0.0      1966           0.0    98042  47.3672 -122.151
# 775           1000.0      1963           0.0    98008  47.6188 -122.114
# 1040           800.0      1976           0.0    98052  47.6830 -122.114
# ...              ...       ...           ...      ...      ...      ...
# 20543          350.0      2009           0.0    98106  47.5489 -122.363
# 20586            0.0      2012           0.0    98065  47.5150 -121.870
# 21145            0.0      2013           0.0    98045  47.4761 -121.734
# 21271         1170.0      2007           0.0    98059  47.5133 -122.110
# 21374            0.0      2006           0.0    98042  47.3358 -122.055
#
#        sqft_living15  sqft_lot15
# 172             1480        7940
# 312             2880        5400
# 502             2200       12825
# 775             2070        8250
# 1040            2200       10500
# ...              ...         ...
# 20543           1590        2306
# 20586           2380        5000
# 21145           2990        6037
# 21271           2730      111274
# 21374           2280        5050
#
# [67 rows x 21 columns]
# Min for price
#              id       date    price  bedrooms  bathrooms  sqft_living  \
# 15279  40000362 2014-05-06  78000.0         2        1.0          780
#
#        sqft_lot  floors  waterfront  view  condition  grade  sqft_above  \
# 15279     16344     1.0         0.0   0.0          1      5         780
#
#        sqft_basement  yr_built  yr_renovated  zipcode      lat    long  \
# 15279            0.0      1942           0.0    98168  47.4739 -122.28
#
#        sqft_living15  sqft_lot15
# 15279           1700       10387
# Min for bedrooms
#                id       date     price  bedrooms  bathrooms  sqft_living  \
# 154    7920100045 2014-05-16  350000.0         1       1.00          700
# 264    2123039032 2014-10-27  369900.0         1       0.75          760
# 350    7325600160 2014-06-04  299000.0         1       0.75          560
# 465    8658300340 2014-05-23   80000.0         1       0.75          430
# 648     922049078 2014-11-18  157000.0         1       1.00          870
# ...           ...        ...       ...       ...        ...          ...
# 21310  6003000851 2014-05-22  353000.0         1       1.00          550
# 21316  9266700190 2015-05-11  245000.0         1       1.00          390
# 21427  3278600750 2015-04-07  250000.0         1       1.50         1180
# 21503  1702901618 2015-04-07  420000.0         1       2.00         1070
# 21536   688000017 2014-06-27  516500.0         1       1.25         1100
#
#        sqft_lot  floors  waterfront  view  condition  grade  sqft_above  \
# 154        5100     1.0         0.0   0.0          3      7         700
# 264       10079     1.0         1.0   4.0          5      5         760
# 350       12120     1.0         0.0   0.0          3      4         560
# 465        5050     1.0         0.0   0.0          2      4         430
# 648       26326     1.0         0.0   0.0          3      6         870
# ...         ...     ...         ...   ...        ...    ...         ...
# 21310      1279     2.0         0.0   0.0          3      7         550
# 21316      2000     1.0         0.0   0.0          4      6         390
# 21427      1688     2.0         0.0   0.0          3      8        1070
# 21503       675     2.0         0.0   0.0          3      8         880
# 21536       638     3.0         0.0   0.0          3      9        1100
#
#        sqft_basement  yr_built  yr_renovated  zipcode      lat     long  \
# 154              0.0      1942           0.0    98115  47.6790 -122.300
# 264              0.0      1936           0.0    98070  47.4683 -122.438
# 350              0.0      1967           0.0    98014  47.6750 -121.854
# 465              0.0      1912           0.0    98014  47.6499 -121.909
# 648              0.0      1939           0.0    98198  47.4152 -122.300
# ...              ...       ...           ...      ...      ...      ...
# 21310            0.0      2008           0.0    98122  47.6160 -122.314
# 21316            0.0      1920           0.0    98103  47.6938 -122.347
# 21427          110.0      2007           0.0    98126  47.5490 -122.372
# 21503          190.0      2007           0.0    98118  47.5574 -122.284
# 21536            0.0      2014           0.0    98112  47.6228 -122.307
#
#        sqft_living15  sqft_lot15
# 154             1010        5100
# 264             1230       14267
# 350             1300       19207
# 465             1200        7500
# 648             1250       10608
# ...              ...         ...
# 21310           1460        1385
# 21316           1340        5100
# 21427           1380        2059
# 21503           1220         788
# 21536           1110        1933
#
# [196 rows x 21 columns]
# Min for bathrooms
#                id       date     price  bedrooms  bathrooms  sqft_living  \
# 2259   3971701455 2014-10-03  273000.0         2        0.5         1180
# 10413  7129800036 2015-01-14  109000.0         2        0.5          580
# 11662  7987400316 2014-08-14  255000.0         1        0.5          880
# 12029  2991000160 2014-12-12  312500.0         4        0.5         2300
#
#        sqft_lot  floors  waterfront  view  condition  grade  sqft_above  \
# 2259       7750     1.0         0.0   0.0          4      6         590
# 10413      6900     1.0         0.0   0.0          3      5         580
# 11662      1642     1.0         0.0   0.0          3      6         500
# 12029      5570     2.0         0.0   0.0          3      8        2300
#
#        sqft_basement  yr_built  yr_renovated  zipcode      lat     long  \
# 2259           590.0      1945           0.0    98155  47.7690 -122.316
# 10413            0.0      1941           0.0    98118  47.5135 -122.262
# 11662          380.0      1910           0.0    98126  47.5732 -122.372
# 12029            0.0      1996           0.0    98092  47.3285 -122.168
#
#        sqft_living15  sqft_lot15
# 2259            1380        8976
# 10413           1570        5040
# 11662           1410        2992
# 12029           1820        6371
# Min for sqft_living
#                id       date     price  bedrooms  bathrooms  sqft_living  \
# 15367  2856101479 2014-07-01  276000.0         1       0.75          370
#
#        sqft_lot  floors  waterfront  view  condition  grade  sqft_above  \
# 15367      1801     1.0         0.0   0.0          5      5         370
#
#        sqft_basement  yr_built  yr_renovated  zipcode      lat     long  \
# 15367            0.0      1923           0.0    98117  47.6778 -122.389
#
#        sqft_living15  sqft_lot15
# 15367           1340        5000
# Min for sqft_lot
#                id       date     price  bedrooms  bathrooms  sqft_living  \
# 15729  9828702895 2014-10-22  700000.0         4       1.75         2420
#
#        sqft_lot  floors  waterfront  view  condition  grade  sqft_above  \
# 15729       520     1.5         0.0   0.0          3      7        2420
#
#        sqft_basement  yr_built  yr_renovated  zipcode      lat     long  \
# 15729            0.0      1900           0.0    98112  47.6209 -122.302
#
#        sqft_living15  sqft_lot15
# 15729           1200        1170
# Min for floors
#                id       date      price  bedrooms  bathrooms  sqft_living  \
# 0      7129300520 2014-10-13   221900.0         3       1.00         1180
# 2      5631500400 2015-02-25   180000.0         2       1.00          770
# 3      2487200875 2014-12-09   604000.0         4       3.00         1960
# 4      1954400510 2015-02-18   510000.0         3       2.00         1680
# 5      7237550310 2014-05-12  1230000.0         4       4.50         5420
# ...           ...        ...        ...       ...        ...          ...
# 21474  9512200090 2015-05-01   529000.0         3       1.75         2340
# 21488  8682291050 2014-07-08   810000.0         2       2.75         2700
# 21514  8964800330 2015-04-07  3000000.0         4       3.75         5090
# 21554  3438501862 2014-05-13   330000.0         3       2.50         1450
# 21586   844000965 2014-06-26   224000.0         3       1.75         1500
#
#        sqft_lot  floors  waterfront  view  condition  grade  sqft_above  \
# 0          5650     1.0         0.0   0.0          3      7        1180
# 2         10000     1.0         0.0   0.0          3      6         770
# 3          5000     1.0         0.0   0.0          5      7        1050
# 4          8080     1.0         0.0   0.0          3      8        1680
# 5        101930     1.0         0.0   0.0          3     11        3890
# ...         ...     ...         ...   ...        ...    ...         ...
# 21474      7724     1.0         0.0   0.0          3     10        2340
# 21488      8572     1.0         0.0   0.0          3      9        2700
# 21514     14823     1.0         0.0   0.0          3     11        4180
# 21554      5008     1.0         0.0   0.0          3      7         840
# 21586     11968     1.0         0.0   0.0          3      6        1500
#
#        sqft_basement  yr_built  yr_renovated  zipcode      lat     long  \
# 0                0.0      1955           0.0    98178  47.5112 -122.257
# 2                0.0      1933           0.0    98028  47.7379 -122.233
# 3              910.0      1965           0.0    98136  47.5208 -122.393
# 4                0.0      1987           0.0    98074  47.6168 -122.045
# 5             1530.0      2001           0.0    98053  47.6561 -122.005
# ...              ...       ...           ...      ...      ...      ...
# 21474            0.0      2010           0.0    98058  47.4593 -122.134
# 21488            0.0      2007           0.0    98053  47.7236 -122.033
# 21514          910.0      2013           0.0    98004  47.6200 -122.207
# 21554          610.0      2007           0.0    98106  47.5435 -122.357
# 21586            0.0      2014           0.0    98010  47.3095 -122.002
#
#        sqft_living15  sqft_lot15
# 0               1340        5650
# 2               2720        8062
# 3               1360        5000
# 4               1800        7503
# 5               4760      101930
# ...              ...         ...
# 21474           3040        5787
# 21488           2680        8569
# 21514           3030       12752
# 21554           2120        5019
# 21586           1320       11303
#
# [10673 rows x 21 columns]
# Min for waterfront
#                id       date     price  bedrooms  bathrooms  sqft_living  \
# 0      7129300520 2014-10-13  221900.0         3       1.00         1180
# 1      6414100192 2014-12-09  538000.0         3       2.25         2570
# 2      5631500400 2015-02-25  180000.0         2       1.00          770
# 3      2487200875 2014-12-09  604000.0         4       3.00         1960
# 4      1954400510 2015-02-18  510000.0         3       2.00         1680
# ...           ...        ...       ...       ...        ...          ...
# 21592   263000018 2014-05-21  360000.0         3       2.50         1530
# 21593  6600060120 2015-02-23  400000.0         4       2.50         2310
# 21594  1523300141 2014-06-23  402101.0         2       0.75         1020
# 21595   291310100 2015-01-16  400000.0         3       2.50         1600
# 21596  1523300157 2014-10-15  325000.0         2       0.75         1020
#
#        sqft_lot  floors  waterfront  view  condition  grade  sqft_above  \
# 0          5650     1.0         0.0   0.0          3      7        1180
# 1          7242     2.0         0.0   0.0          3      7        2170
# 2         10000     1.0         0.0   0.0          3      6         770
# 3          5000     1.0         0.0   0.0          5      7        1050
# 4          8080     1.0         0.0   0.0          3      8        1680
# ...         ...     ...         ...   ...        ...    ...         ...
# 21592      1131     3.0         0.0   0.0          3      8        1530
# 21593      5813     2.0         0.0   0.0          3      8        2310
# 21594      1350     2.0         0.0   0.0          3      7        1020
# 21595      2388     2.0         0.0   0.0          3      8        1600
# 21596      1076     2.0         0.0   0.0          3      7        1020
#
#        sqft_basement  yr_built  yr_renovated  zipcode      lat     long  \
# 0                0.0      1955           0.0    98178  47.5112 -122.257
# 1              400.0      1951        1991.0    98125  47.7210 -122.319
# 2                0.0      1933           0.0    98028  47.7379 -122.233
# 3              910.0      1965           0.0    98136  47.5208 -122.393
# 4                0.0      1987           0.0    98074  47.6168 -122.045
# ...              ...       ...           ...      ...      ...      ...
# 21592            0.0      2009           0.0    98103  47.6993 -122.346
# 21593            0.0      2014           0.0    98146  47.5107 -122.362
# 21594            0.0      2009           0.0    98144  47.5944 -122.299
# 21595            0.0      2004           0.0    98027  47.5345 -122.069
# 21596            0.0      2008           0.0    98144  47.5941 -122.299
#
#        sqft_living15  sqft_lot15
# 0               1340        5650
# 1               1690        7639
# 2               2720        8062
# 3               1360        5000
# 4               1800        7503
# ...              ...         ...
# 21592           1530        1509
# 21593           1830        7200
# 21594           1020        2007
# 21595           1410        1287
# 21596           1020        1357
#
# [21451 rows x 21 columns]
# Min for view
#                id       date     price  bedrooms  bathrooms  sqft_living  \
# 0      7129300520 2014-10-13  221900.0         3       1.00         1180
# 1      6414100192 2014-12-09  538000.0         3       2.25         2570
# 2      5631500400 2015-02-25  180000.0         2       1.00          770
# 3      2487200875 2014-12-09  604000.0         4       3.00         1960
# 4      1954400510 2015-02-18  510000.0         3       2.00         1680
# ...           ...        ...       ...       ...        ...          ...
# 21592   263000018 2014-05-21  360000.0         3       2.50         1530
# 21593  6600060120 2015-02-23  400000.0         4       2.50         2310
# 21594  1523300141 2014-06-23  402101.0         2       0.75         1020
# 21595   291310100 2015-01-16  400000.0         3       2.50         1600
# 21596  1523300157 2014-10-15  325000.0         2       0.75         1020
#
#        sqft_lot  floors  waterfront  view  condition  grade  sqft_above  \
# 0          5650     1.0         0.0   0.0          3      7        1180
# 1          7242     2.0         0.0   0.0          3      7        2170
# 2         10000     1.0         0.0   0.0          3      6         770
# 3          5000     1.0         0.0   0.0          5      7        1050
# 4          8080     1.0         0.0   0.0          3      8        1680
# ...         ...     ...         ...   ...        ...    ...         ...
# 21592      1131     3.0         0.0   0.0          3      8        1530
# 21593      5813     2.0         0.0   0.0          3      8        2310
# 21594      1350     2.0         0.0   0.0          3      7        1020
# 21595      2388     2.0         0.0   0.0          3      8        1600
# 21596      1076     2.0         0.0   0.0          3      7        1020
#
#        sqft_basement  yr_built  yr_renovated  zipcode      lat     long  \
# 0                0.0      1955           0.0    98178  47.5112 -122.257
# 1              400.0      1951        1991.0    98125  47.7210 -122.319
# 2                0.0      1933           0.0    98028  47.7379 -122.233
# 3              910.0      1965           0.0    98136  47.5208 -122.393
# 4                0.0      1987           0.0    98074  47.6168 -122.045
# ...              ...       ...           ...      ...      ...      ...
# 21592            0.0      2009           0.0    98103  47.6993 -122.346
# 21593            0.0      2014           0.0    98146  47.5107 -122.362
# 21594            0.0      2009           0.0    98144  47.5944 -122.299
# 21595            0.0      2004           0.0    98027  47.5345 -122.069
# 21596            0.0      2008           0.0    98144  47.5941 -122.299
#
#        sqft_living15  sqft_lot15
# 0               1340        5650
# 1               1690        7639
# 2               2720        8062
# 3               1360        5000
# 4               1800        7503
# ...              ...         ...
# 21592           1530        1509
# 21593           1830        7200
# 21594           1020        2007
# 21595           1410        1287
# 21596           1020        1357
#
# [19485 rows x 21 columns]
# Min for condition
#                id       date      price  bedrooms  bathrooms  sqft_living  \
# 36     9435300030 2014-05-28   550000.0         4       1.00         1660
# 380    1726059053 2014-09-16   270000.0         2       1.50         1380
# 397    5175800060 2014-06-23   365000.0         4       2.00         1940
# 1440   5694000710 2014-11-07   352950.0         3       1.00         1760
# 1732    913000340 2015-01-02   252000.0         1       1.00          680
# 2221   3886902445 2015-03-16   535000.0         2       1.00          920
# 3002   9187200245 2014-12-31   441000.0         4       1.50         1100
# 3199    723049596 2014-05-09   255000.0         2       1.00          810
# 3971   6324000090 2015-05-11   210000.0         2       1.00          990
# 4647    859000110 2014-10-02   125000.0         1       1.00          500
# 7369   9275200080 2014-11-07   295000.0         3       1.50          720
# 7629   4008400515 2015-01-20   190000.0         1       0.75          780
# 12294  2570600140 2015-01-28   196000.0         3       2.25         1510
# 12441  4022900951 2015-04-02   305000.0         2       1.00          910
# 12655  4006000281 2014-07-29   227000.0         3       1.75         2380
# 13615  2023049218 2014-07-16   105500.0         2       1.00          930
# 13616  2023049218 2015-03-16   445000.0         2       1.00          930
# 14973  9187200095 2014-12-02   432500.0         6       2.00         3080
# 15279    40000362 2014-05-06    78000.0         2       1.00          780
# 15323  7849200635 2014-06-30   235000.0         2       1.00          900
# 15357  7936500221 2015-01-14   658000.0         2       1.00         1010
# 15698  3089000005 2014-07-24   150000.0         2       1.00          850
# 16184  3028200080 2015-03-24    81000.0         2       1.00          730
# 16879  3501100050 2014-12-10   125000.0         3       1.00         1230
# 16928  5015001680 2014-06-11   427000.0         4       1.00         1860
# 17791  2206900065 2015-05-01   380000.0         3       1.50         1430
# 18318  9272202260 2014-09-24   130000.0         3       1.00         1200
# 18630  7942600910 2014-12-16   575000.0         1       1.00         1310
# 18861  9808700025 2015-02-11  1500000.0         3       1.50         1910
#
#        sqft_lot  floors  waterfront  view  condition  grade  sqft_above  \
# 36        34848     1.0         0.0   0.0          1      5         930
# 380      209959     1.0         0.0   0.0          1      6        1380
# 397       25600     1.0         0.0   0.0          1      8        1940
# 1440       3000     1.5         0.0   0.0          1      6        1760
# 1732       1638     1.0         0.0   4.0          1      6         680
# 2221       9000     1.0         0.0   0.0          1      6         920
# 3002       3300     1.0         0.0   0.0          1      7        1100
# 3199       7980     1.0         0.0   0.0          1      6         810
# 3971       8140     1.0         0.0   0.0          1      6         990
# 4647       7440     1.0         0.0   0.0          1      5         500
# 7369       7450     1.0         0.0   1.0          1      5         720
# 7629      77603     1.0         0.0   0.0          1      5         780
# 12294      9600     1.0         0.0   0.0          1      7        1090
# 12441     22725     1.0         0.0   0.0          1      6         910
# 12655     12681     1.0         0.0   0.0          1      6        1380
# 13615      7740     1.0         0.0   0.0          1      5         930
# 13616      7740     1.0         0.0   0.0          1      5         930
# 14973      5500     2.0         0.0   0.0          1      7        3080
# 15279     16344     1.0         0.0   0.0          1      5         780
# 15323     28800     1.0         0.0   0.0          1      6         900
# 15357     14244     1.0         1.0   4.0          1      5        1010
# 15698     54000     1.5         0.0   0.0          1      4         850
# 16184      9975     1.0         0.0   0.0          1      5         730
# 16879      4800     1.5         0.0   0.0          1      6        1230
# 16928      4736     1.5         0.0   0.0          1      7        1860
# 17791     11173     1.0         0.0   0.0          1      7        1430
# 18318      7000     2.0         0.0   0.0          1      7        1200
# 18630      8667     1.5         0.0   0.0          1      6        1310
# 18861     21374     1.0         0.0   0.0          1      8        1910
#
#        sqft_basement  yr_built  yr_renovated  zipcode      lat     long  \
# 36             730.0      1933           0.0    98052  47.6621 -122.132
# 380              0.0      1954           0.0    98011  47.7461 -122.195
# 397              0.0      1962           0.0    98006  47.5722 -122.129
# 1440             0.0      1900           0.0    98103  47.6598 -122.348
# 1732             0.0      1910        1992.0    98116  47.5832 -122.399
# 2221             0.0      1954           0.0    98033  47.6831 -122.189
# 3002             0.0      1919           0.0    98122  47.6033 -122.295
# 3199             0.0      1928           0.0    98146  47.4890 -122.337
# 3971             0.0      1910           0.0    98116  47.5828 -122.382
# 4647             0.0      1928           0.0    98106  47.5252 -122.362
# 7369             0.0      1924           0.0    98126  47.5840 -122.375
# 7629             0.0      1945           0.0    98058  47.4396 -122.104
# 12294          420.0      1966           0.0    98028  47.7758 -122.238
# 12441            0.0      1926           0.0    98155  47.7712 -122.299
# 12655         1000.0      1918           0.0    98118  47.5294 -122.279
# 13615            0.0      1932           0.0    98148  47.4611 -122.324
# 13616            0.0      1932           0.0    98148  47.4611 -122.324
# 14973            0.0      1900           0.0    98122  47.6031 -122.296
# 15279            0.0      1942           0.0    98168  47.4739 -122.280
# 15323            0.0      1928           0.0    98065  47.5245 -121.822
# 15357            0.0      1926           0.0    98136  47.5476 -122.399
# 15698            0.0      1950           0.0    98023  47.2959 -122.377
# 16184            0.0      1943           0.0    98168  47.4808 -122.315
# 16879            0.0      1916           0.0    98117  47.6941 -122.365
# 16928            0.0      1901           0.0    98112  47.6251 -122.300
# 17791            0.0      1955           0.0    98006  47.5734 -122.153
# 18318            0.0      1908           0.0    98116  47.5883 -122.384
# 18630            0.0      1918           0.0    98122  47.6059 -122.313
# 18861            0.0      1955           0.0    98004  47.6453 -122.214
#
#        sqft_living15  sqft_lot15
# 36              2160       11467
# 380             3130       19868
# 397             2000       10071
# 1440            1320        1266
# 1732            1010        3621
# 2221            1760        8400
# 3002            2020        4000
# 3199            1440        7980
# 3971            2150        5000
# 4647            1350        7440
# 7369            2600        7360
# 7629            1750       30847
# 12294           1870       10681
# 12441           2000       14566
# 12655           1720        6377
# 13615           1620        8584
# 13616           1620        8584
# 14973           1830        5000
# 15279           1700       10387
# 15323           1360        7200
# 15357           1820       15792
# 15698           1550       14440
# 16184            860        9000
# 16879           1230        4800
# 16928           1800        4000
# 17791           1520       11659
# 18318           3290        6000
# 18630           1130        4800
# 18861           2850       16167
# Min for grade
#               id       date     price  bedrooms  bathrooms  sqft_living  \
# 3220  2420069251 2015-02-25  262000.0         1       0.75          520
#
#       sqft_lot  floors  waterfront  view  condition  grade  sqft_above  \
# 3220     12981     1.0         0.0   0.0          5      3         520
#
#       sqft_basement  yr_built  yr_renovated  zipcode      lat     long  \
# 3220            0.0      1920           0.0    98022  47.2082 -121.995
#
#       sqft_living15  sqft_lot15
# 3220           1340       12233
# Min for sqft_above
#                id       date     price  bedrooms  bathrooms  sqft_living  \
# 15367  2856101479 2014-07-01  276000.0         1       0.75          370
#
#        sqft_lot  floors  waterfront  view  condition  grade  sqft_above  \
# 15367      1801     1.0         0.0   0.0          5      5         370
#
#        sqft_basement  yr_built  yr_renovated  zipcode      lat     long  \
# 15367            0.0      1923           0.0    98117  47.6778 -122.389
#
#        sqft_living15  sqft_lot15
# 15367           1340        5000
# Min for sqft_basement
#                id       date     price  bedrooms  bathrooms  sqft_living  \
# 0      7129300520 2014-10-13  221900.0         3       1.00         1180
# 2      5631500400 2015-02-25  180000.0         2       1.00          770
# 4      1954400510 2015-02-18  510000.0         3       2.00         1680
# 6      1321400060 2014-06-27  257500.0         3       2.25         1715
# 7      2008000270 2015-01-15  291850.0         3       1.50         1060
# ...           ...        ...       ...       ...        ...          ...
# 21592   263000018 2014-05-21  360000.0         3       2.50         1530
# 21593  6600060120 2015-02-23  400000.0         4       2.50         2310
# 21594  1523300141 2014-06-23  402101.0         2       0.75         1020
# 21595   291310100 2015-01-16  400000.0         3       2.50         1600
# 21596  1523300157 2014-10-15  325000.0         2       0.75         1020
#
#        sqft_lot  floors  waterfront  view  condition  grade  sqft_above  \
# 0          5650     1.0         0.0   0.0          3      7        1180
# 2         10000     1.0         0.0   0.0          3      6         770
# 4          8080     1.0         0.0   0.0          3      8        1680
# 6          6819     2.0         0.0   0.0          3      7        1715
# 7          9711     1.0         0.0   0.0          3      7        1060
# ...         ...     ...         ...   ...        ...    ...         ...
# 21592      1131     3.0         0.0   0.0          3      8        1530
# 21593      5813     2.0         0.0   0.0          3      8        2310
# 21594      1350     2.0         0.0   0.0          3      7        1020
# 21595      2388     2.0         0.0   0.0          3      8        1600
# 21596      1076     2.0         0.0   0.0          3      7        1020
#
#        sqft_basement  yr_built  yr_renovated  zipcode      lat     long  \
# 0                0.0      1955           0.0    98178  47.5112 -122.257
# 2                0.0      1933           0.0    98028  47.7379 -122.233
# 4                0.0      1987           0.0    98074  47.6168 -122.045
# 6                0.0      1995           0.0    98003  47.3097 -122.327
# 7                0.0      1963           0.0    98198  47.4095 -122.315
# ...              ...       ...           ...      ...      ...      ...
# 21592            0.0      2009           0.0    98103  47.6993 -122.346
# 21593            0.0      2014           0.0    98146  47.5107 -122.362
# 21594            0.0      2009           0.0    98144  47.5944 -122.299
# 21595            0.0      2004           0.0    98027  47.5345 -122.069
# 21596            0.0      2008           0.0    98144  47.5941 -122.299
#
#        sqft_living15  sqft_lot15
# 0               1340        5650
# 2               2720        8062
# 4               1800        7503
# 6               2238        6819
# 7               1650        9711
# ...              ...         ...
# 21592           1530        1509
# 21593           1830        7200
# 21594           1020        2007
# 21595           1410        1287
# 21596           1020        1357
#
# [13280 rows x 21 columns]
# Min for yr_built
#                id       date     price  bedrooms  bathrooms  sqft_living  \
# 14     1175000570 2015-03-12  530000.0         5       2.00         1810
# 115    3626039325 2014-11-21  740500.0         3       3.50         4380
# 498    9274202270 2014-08-18  625000.0         2       1.50         1490
# 537    5694500105 2014-12-04  595000.0         2       2.00         1510
# 703    7011200260 2014-12-19  485000.0         4       2.00         1400
# ...           ...        ...       ...       ...        ...          ...
# 19048  1702901340 2014-06-13  718500.0         3       2.00         2910
# 19122  3388110230 2014-07-29  179000.0         4       1.75         1790
# 19304  4083302225 2014-10-14  850000.0         4       3.00         2550
# 19370  2420069042 2015-04-24  240000.0         3       2.00         1553
# 19582  7518507685 2015-02-23  400000.0         3       1.00         1100
#
#        sqft_lot  floors  waterfront  view  condition  grade  sqft_above  \
# 14         4850     1.5         0.0   0.0          3      7        1810
# 115        6350     2.0         0.0   0.0          3      8        2780
# 498        5750     1.5         0.0   0.0          4      7        1190
# 537        4000     1.0         0.0   0.0          4      7        1010
# 703        3600     1.0         0.0   0.0          3      7        1100
# ...         ...     ...         ...   ...        ...    ...         ...
# 19048      6600     2.0         0.0   0.0          4      7        1920
# 19122      7175     1.5         0.0   0.0          3      6        1410
# 19304      3784     1.5         0.0   0.0          4      8        1750
# 19370      6550     1.0         0.0   0.0          3      7        1553
# 19582      5100     2.0         0.0   0.0          4      7        1100
#
#        sqft_basement  yr_built  yr_renovated  zipcode      lat     long  \
# 14               0.0      1900           0.0    98107  47.6700 -122.394
# 115              0.0      1900           0.0    98117  47.6981 -122.368
# 498            300.0      1900           0.0    98116  47.5872 -122.390
# 537            500.0      1900           0.0    98103  47.6582 -122.345
# 703            300.0      1900           0.0    98119  47.6385 -122.370
# ...              ...       ...           ...      ...      ...      ...
# 19048          990.0      1900           0.0    98118  47.5576 -122.281
# 19122          380.0      1900           0.0    98168  47.4963 -122.318
# 19304          800.0      1900           0.0    98103  47.6559 -122.338
# 19370            0.0      1900           0.0    98022  47.2056 -121.994
# 19582            0.0      1900           0.0    98117  47.6790 -122.386
#
#        sqft_living15  sqft_lot15
# 14              1360        4850
# 115             1830        6350
# 498             1590        4025
# 537             1920        4000
# 703             1630        2048
# ...              ...         ...
# 19048           1370        5500
# 19122           1790        8417
# 19304           2100        4560
# 19370           1010       10546
# 19582           1540        5100
#
# [87 rows x 21 columns]
# Min for yr_renovated
#                id       date      price  bedrooms  bathrooms  sqft_living  \
# 0      7129300520 2014-10-13   221900.0         3       1.00         1180
# 2      5631500400 2015-02-25   180000.0         2       1.00          770
# 3      2487200875 2014-12-09   604000.0         4       3.00         1960
# 4      1954400510 2015-02-18   510000.0         3       2.00         1680
# 5      7237550310 2014-05-12  1230000.0         4       4.50         5420
# ...           ...        ...        ...       ...        ...          ...
# 21592   263000018 2014-05-21   360000.0         3       2.50         1530
# 21593  6600060120 2015-02-23   400000.0         4       2.50         2310
# 21594  1523300141 2014-06-23   402101.0         2       0.75         1020
# 21595   291310100 2015-01-16   400000.0         3       2.50         1600
# 21596  1523300157 2014-10-15   325000.0         2       0.75         1020
#
#        sqft_lot  floors  waterfront  view  condition  grade  sqft_above  \
# 0          5650     1.0         0.0   0.0          3      7        1180
# 2         10000     1.0         0.0   0.0          3      6         770
# 3          5000     1.0         0.0   0.0          5      7        1050
# 4          8080     1.0         0.0   0.0          3      8        1680
# 5        101930     1.0         0.0   0.0          3     11        3890
# ...         ...     ...         ...   ...        ...    ...         ...
# 21592      1131     3.0         0.0   0.0          3      8        1530
# 21593      5813     2.0         0.0   0.0          3      8        2310
# 21594      1350     2.0         0.0   0.0          3      7        1020
# 21595      2388     2.0         0.0   0.0          3      8        1600
# 21596      1076     2.0         0.0   0.0          3      7        1020
#
#        sqft_basement  yr_built  yr_renovated  zipcode      lat     long  \
# 0                0.0      1955           0.0    98178  47.5112 -122.257
# 2                0.0      1933           0.0    98028  47.7379 -122.233
# 3              910.0      1965           0.0    98136  47.5208 -122.393
# 4                0.0      1987           0.0    98074  47.6168 -122.045
# 5             1530.0      2001           0.0    98053  47.6561 -122.005
# ...              ...       ...           ...      ...      ...      ...
# 21592            0.0      2009           0.0    98103  47.6993 -122.346
# 21593            0.0      2014           0.0    98146  47.5107 -122.362
# 21594            0.0      2009           0.0    98144  47.5944 -122.299
# 21595            0.0      2004           0.0    98027  47.5345 -122.069
# 21596            0.0      2008           0.0    98144  47.5941 -122.299
#
#        sqft_living15  sqft_lot15
# 0               1340        5650
# 2               2720        8062
# 3               1360        5000
# 4               1800        7503
# 5               4760      101930
# ...              ...         ...
# 21592           1530        1509
# 21593           1830        7200
# 21594           1020        2007
# 21595           1410        1287
# 21596           1020        1357
#
# [20853 rows x 21 columns]
# Min for zipcode
#                id       date     price  bedrooms  bathrooms  sqft_living  \
# 38     7895500070 2015-02-13  240000.0         4       1.00         1220
# 67     3717000160 2014-10-09  287000.0         4       2.50         2240
# 114    8961960160 2014-10-28  480000.0         4       2.50         3230
# 213    4014400292 2015-01-14  465000.0         3       2.50         2714
# 292    1115450240 2014-10-22  360000.0         4       2.50         2160
# ...           ...        ...       ...       ...        ...          ...
# 21375  3094000210 2015-01-05  269950.0         3       2.50         2244
# 21463  6181500120 2014-06-23  312891.0         5       3.00         2300
# 21495  3304030220 2015-04-21  480000.0         4       2.50         2940
# 21549  5007500120 2015-02-26  341780.0         4       2.75         2260
# 21582  8956200760 2014-10-13  541800.0         4       2.50         3118
#
#        sqft_lot  floors  waterfront  view  condition  grade  sqft_above  \
# 38         8075     1.0         0.0   0.0          2      7         890
# 67         4648     2.0         0.0   0.0          3      7        2240
# 114       16171     2.0         0.0   0.0          3      9        2520
# 213       17936     2.0         0.0   0.0          3      9        2714
# 292        9528     2.0         0.0   0.0          3      9        2160
# ...         ...     ...         ...   ...        ...    ...         ...
# 21375      4079     2.0         0.0   0.0          3      7        2244
# 21463      8214     2.0         0.0   0.0          3      8        2300
# 21495      9172     2.0         0.0   0.0          3      9        2940
# 21549      4440     2.0         0.0   0.0          3      7        2260
# 21582      7866     2.0         0.0   2.0          3      9        3118
#
#        sqft_basement  yr_built  yr_renovated  zipcode      lat     long  \
# 38             330.0      1969           0.0    98001  47.3341 -122.282
# 67               0.0      2005           0.0    98001  47.3378 -122.257
# 114            710.0      2001           0.0    98001  47.3183 -122.253
# 213              0.0      2005           0.0    98001  47.3185 -122.275
# 292              0.0      1992           0.0    98001  47.3341 -122.255
# ...              ...       ...           ...      ...      ...      ...
# 21375            0.0      2012           0.0    98001  47.2606 -122.254
# 21463            0.0      2013           0.0    98001  47.3052 -122.276
# 21495            0.0      2006           0.0    98001  47.3444 -122.269
# 21549            0.0      2014           0.0    98001  47.3507 -122.291
# 21582            0.0      2014           0.0    98001  47.2931 -122.264
#
#        sqft_living15  sqft_lot15
# 38              1290        7800
# 67              2221        4557
# 114             2640        8517
# 213             2590       18386
# 292             2280        9937
# ...              ...         ...
# 21375           2077        4078
# 21463           2594        4950
# 21495           2660        7955
# 21549           2260        4563
# 21582           2673        6500
#
# [361 rows x 21 columns]
# Min for lat
#               id       date     price  bedrooms  bathrooms  sqft_living  \
# 3292  9413400165 2014-06-24  380000.0         3       2.25         1860
#
#       sqft_lot  floors  waterfront  view  condition  grade  sqft_above  \
# 3292     15559     2.0         0.0   0.0          4      7        1860
#
#       sqft_basement  yr_built  yr_renovated  zipcode      lat     long  \
# 3292            0.0      1963           0.0    98022  47.1559 -121.646
#
#       sqft_living15  sqft_lot15
# 3292           1110       11586
# Min for long
#                id       date     price  bedrooms  bathrooms  sqft_living  \
# 13873  3522029124 2014-12-03  575000.0         3        2.0         2690
#
#        sqft_lot  floors  waterfront  view  condition  grade  sqft_above  \
# 13873    435600     2.0         0.0   0.0          3      8        2690
#
#        sqft_basement  yr_built  yr_renovated  zipcode      lat     long  \
# 13873            0.0      1992           0.0    98070  47.3477 -122.519
#
#        sqft_living15  sqft_lot15
# 13873           1700      163350
# Min for sqft_living15
#                id       date     price  bedrooms  bathrooms  sqft_living  \
# 13428  2722059275 2015-05-12  536000.0         3       2.75         2290
#
#        sqft_lot  floors  waterfront  view  condition  grade  sqft_above  \
# 13428     34548     2.0         0.0   3.0          4      7        2290
#
#        sqft_basement  yr_built  yr_renovated  zipcode      lat     long  \
# 13428            0.0      1984           0.0    98042  47.3691 -122.163
#
#        sqft_living15  sqft_lot15
# 13428            399      275299
# Min for sqft_lot15
#                id       date     price  bedrooms  bathrooms  sqft_living  \
# 19653  7899800863 2014-10-01  299900.0         3        2.5         1210
#
#        sqft_lot  floors  waterfront  view  condition  grade  sqft_above  \
# 19653      2046     2.0         0.0   0.0          3      9         920
#
#        sqft_basement  yr_built  yr_renovated  zipcode      lat     long  \
# 19653          290.0      2008           0.0    98106  47.5212 -122.357
#
#        sqft_living15  sqft_lot15
# 19653           1070         651

# %% [markdown]
# Potential bad data
# * price - 78,000 may be too odd.  Need to look at other low values.
# * bathrooms - 0.5 with 4 bedrooms seems odd especially for a grade 8 house at 2300 sqft_living

# %% [markdown]
# #### Look for duplicate ids

# %%
duplicated_rows = df_clean.duplicated()

# %%
duplicated_rows.value_counts()
# Out:
# False    21597
# dtype: int64

# %% [markdown]
# There are no duplicate rows.

# %%
duplicated_rows = df_clean.duplicated(subset='id', keep=False)

# %%
df_clean[duplicated_rows]
# Out:
#                id       date      price  bedrooms  bathrooms  sqft_living  \
# 93     6021501535 2014-07-25   430000.0         3       1.50         1580
# 94     6021501535 2014-12-23   700000.0         3       1.50         1580
# 313    4139480200 2014-06-18  1380000.0         4       3.25         4290
# 314    4139480200 2014-12-09  1400000.0         4       3.25         4290
# 324    7520000520 2014-09-05   232000.0         2       1.00         1240
# ...           ...        ...        ...       ...        ...          ...
# 20654  8564860270 2015-03-30   502000.0         4       2.50         2680
# 20763  6300000226 2014-06-26   240000.0         4       1.00         1200
# 20764  6300000226 2015-05-04   380000.0         4       1.00         1200
# 21564  7853420110 2014-10-03   594866.0         3       3.00         2780
# 21565  7853420110 2015-05-04   625000.0         3       3.00         2780
#
#        sqft_lot  floors  waterfront  view  condition  grade  sqft_above  \
# 93         5000     1.0         0.0   0.0          3      8        1290
# 94         5000     1.0         0.0   0.0          3      8        1290
# 313       12103     1.0         0.0   3.0          3     11        2690
# 314       12103     1.0         0.0   3.0          3     11        2690
# 324       12092     1.0         0.0   0.0          3      6         960
# ...         ...     ...         ...   ...        ...    ...         ...
# 20654      5539     2.0         0.0   0.0          3      8        2680
# 20763      2171     1.5         0.0   0.0          3      7        1200
# 20764      2171     1.5         0.0   0.0          3      7        1200
# 21564      6000     2.0         0.0   0.0          3      9        2780
# 21565      6000     2.0         0.0   0.0          3      9        2780
#
#        sqft_basement  yr_built  yr_renovated  zipcode      lat     long  \
# 93             290.0      1939           0.0    98117  47.6870 -122.386
# 94             290.0      1939           0.0    98117  47.6870 -122.386
# 313           1600.0      1997           0.0    98006  47.5503 -122.102
# 314           1600.0      1997           0.0    98006  47.5503 -122.102
# 324            280.0      1922        1984.0    98146  47.4957 -122.352
# ...              ...       ...           ...      ...      ...      ...
# 20654            0.0      2013           0.0    98045  47.4759 -121.734
# 20763            0.0      1933           0.0    98133  47.7076 -122.342
# 20764            0.0      1933           0.0    98133  47.7076 -122.342
# 21564            0.0      2013           0.0    98065  47.5184 -121.886
# 21565            0.0      2013           0.0    98065  47.5184 -121.886
#
#        sqft_living15  sqft_lot15
# 93              1570        4500
# 94              1570        4500
# 313             3860       11244
# 314             3860       11244
# 324             1820        7460
# ...              ...         ...
# 20654           2680        5992
# 20763           1130        1598
# 20764           1130        1598
# 21564           2850        6000
# 21565           2850        6000
#
# [353 rows x 21 columns]

# %% [markdown]
# There are 353 rows of properties with multiple sales.

# %%
df_clean[duplicated_rows][df_clean.yr_renovated != 0]
# Out:
# /Users/freethrall/anaconda3/envs/learn-env/lib/python3.6/site-packages/ipykernel_launcher.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   """Entry point for launching an IPython kernel.
#               id       date     price  bedrooms  bathrooms  sqft_living  \
# 324   7520000520 2014-09-05  232000.0         2       1.00         1240
# 325   7520000520 2015-03-11  240500.0         2       1.00         1240
# 717   8820903380 2014-07-28  452000.0         6       2.25         2660
# 718   8820903380 2015-01-02  730000.0         6       2.25         2660
# 3946  1825069031 2014-08-14  550000.0         4       1.75         2410
# 3947  1825069031 2014-10-16  550000.0         4       1.75         2410
# 8426  1721801010 2014-09-03  225000.0         3       1.00         1790
# 8427  1721801010 2015-04-24  302100.0         3       1.00         1790
#
#       sqft_lot  floors  waterfront  view  condition  grade  sqft_above  \
# 324      12092     1.0         0.0   0.0          3      6         960
# 325      12092     1.0         0.0   0.0          3      6         960
# 717      13579     2.0         0.0   0.0          3      7        2660
# 718      13579     2.0         0.0   0.0          3      7        2660
# 3946      8447     2.0         0.0   3.0          4      8        2060
# 3947      8447     2.0         0.0   3.0          4      8        2060
# 8426      6120     1.0         0.0   0.0          3      6        1790
# 8427      6120     1.0         0.0   0.0          3      6        1790
#
#       sqft_basement  yr_built  yr_renovated  zipcode      lat     long  \
# 324           280.0      1922        1984.0    98146  47.4957 -122.352
# 325           280.0      1922        1984.0    98146  47.4957 -122.352
# 717             0.0      1937        1990.0    98125  47.7142 -122.286
# 718             0.0      1937        1990.0    98125  47.7142 -122.286
# 3946          350.0      1936        1980.0    98074  47.6499 -122.088
# 3947          350.0      1936        1980.0    98074  47.6499 -122.088
# 8426            0.0      1937        1964.0    98146  47.5080 -122.337
# 8427            0.0      1937        1964.0    98146  47.5080 -122.337
#
#       sqft_living15  sqft_lot15
# 324            1820        7460
# 325            1820        7460
# 717            1120        8242
# 718            1120        8242
# 3946           2520       14789
# 3947           2520       14789
# 8426            830        6120
# 8427            830        6120

# %% [markdown]
# None of the houses that are marked as renovated, were renovated in between sales, so for all the properties
# with multiple sales, only the most recent sale should be included.
#
# The dataframe is sorted by id and sale date, so the last occurrence can be kept.

# %% [markdown]
# #### Look at the houses with more bathrooms than bedrooms

# %%
df_clean[df_clean.bathrooms > df_clean.bedrooms].describe()
# Out:
#                  id         price    bedrooms   bathrooms   sqft_living  \
# count  8.700000e+02  8.700000e+02  870.000000  870.000000    870.000000
# mean   4.639373e+09  8.407679e+05    2.686207    3.168966   2575.634483
# std    2.919721e+09  7.523344e+05    0.831856    0.899375   1548.456272
# min    1.150131e+07  1.150000e+05    1.000000    1.250000    730.000000
# 25%    2.254752e+09  4.193925e+05    2.000000    2.500000   1460.000000
# 50%    3.771930e+09  6.000000e+05    3.000000    3.250000   2080.000000
# 75%    7.560000e+09  9.299875e+05    3.000000    3.500000   3317.500000
# max    9.831200e+09  7.700000e+06    7.000000    8.000000  13540.000000
#
#             sqft_lot      floors  waterfront        view   condition  \
# count     870.000000  870.000000  870.000000  870.000000  870.000000
# mean    19750.889655    2.013218    0.032184    0.589655    3.197701
# std     68122.210243    0.532703    0.176590    1.217681    0.493916
# min       609.000000    1.000000    0.000000    0.000000    3.000000
# 25%      1449.750000    2.000000    0.000000    0.000000    3.000000
# 50%      4080.000000    2.000000    0.000000    0.000000    3.000000
# 75%     11017.250000    2.000000    0.000000    0.000000    3.000000
# max    982278.000000    3.500000    1.000000    4.000000    5.000000
#
#             grade   sqft_above  sqft_basement     yr_built  yr_renovated  \
# count  870.000000   870.000000     870.000000   870.000000    870.000000
# mean     8.651724  2174.897701     388.322989  1992.758621     94.005747
# std      1.386053  1277.131055     549.681571    24.768184    422.959265
# min      4.000000   550.000000       0.000000  1900.000000      0.000000
# 25%      8.000000  1260.000000       0.000000  1988.000000      0.000000
# 50%      8.000000  1720.000000     210.000000  2004.000000      0.000000
# 75%      9.000000  2730.000000     600.000000  2007.000000      0.000000
# max     13.000000  9410.000000    4820.000000  2015.000000   2014.000000
#
#             zipcode         lat        long  sqft_living15     sqft_lot15
# count    870.000000  870.000000  870.000000     870.000000     870.000000
# mean   98087.050575   47.602206 -122.238630    2142.316092   14752.810345
# std       49.088209    0.098979    0.143627     900.206790   45282.114011
# min    98001.000000   47.241600 -122.505000     850.000000     748.000000
# 25%    98042.000000   47.548225 -122.356750    1450.000000    1766.500000
# 50%    98103.000000   47.620600 -122.291000    1835.000000    4790.000000
# 75%    98118.000000   47.672625 -122.128500    2660.000000   10254.250000
# max    98199.000000   47.776000 -121.736000    6110.000000  858132.000000

# %% [markdown]
# With 863 properties, this doesn't seem to be a good consideration for bad data.

# %% [markdown]
# #### Clean "bad" data

# %% [markdown]
# **Duplicate properties**

# %%
df_clean = df_clean.drop_duplicates(subset='id', keep='last')

# %% [markdown]
# **33 bedrooms**

# %%
df_clean = df_clean.drop(df_clean[df_clean.bedrooms == 33].index)

# %% [markdown]
# look at the new max bedrooms

# %%
df_clean.nlargest(10, 'bedrooms')
# Out:
#                id       date      price  bedrooms  bathrooms  sqft_living  \
# 8748   1773100755 2014-08-21   520000.0        11       3.00         3000
# 13301   627300145 2014-08-14  1150000.0        10       5.25         4590
# 15147  5566100170 2014-10-29   650000.0        10       2.00         3610
# 19239  8812401450 2014-12-29   660000.0        10       3.00         2920
# 4092   1997200215 2014-05-07   599999.0         9       4.50         3830
# 4231   2902200015 2015-01-06   700000.0         9       3.00         3680
# 6073   9822700190 2014-08-08  1280000.0         9       4.50         3650
# 8537    424049043 2014-08-11   450000.0         9       7.50         4050
# 16830  8823900290 2015-03-17  1400000.0         9       4.00         4620
# 18428  8823901445 2015-03-13   934000.0         9       3.00         2820
#
#        sqft_lot  floors  waterfront  view  condition  grade  sqft_above  \
# 8748       4960     2.0         0.0   0.0          3      7        2400
# 13301     10920     1.0         0.0   2.0          3      9        2500
# 15147     11914     2.0         0.0   0.0          4      7        3010
# 19239      3745     2.0         0.0   0.0          4      7        1860
# 4092       6988     2.5         0.0   0.0          3      7        2450
# 4231       4400     2.0         0.0   0.0          3      7        2830
# 6073       5000     2.0         0.0   0.0          3      8        2530
# 8537       6504     2.0         0.0   0.0          3      7        4050
# 16830      5508     2.5         0.0   0.0          3     11        3870
# 18428      4480     2.0         0.0   0.0          3      7        1880
#
#        sqft_basement  yr_built  yr_renovated  zipcode      lat     long  \
# 8748           600.0      1918        1999.0    98106  47.5560 -122.363
# 13301         2090.0      2008           0.0    98004  47.5861 -122.113
# 15147          600.0      1958           0.0    98006  47.5705 -122.175
# 19239         1060.0      1913           0.0    98105  47.6635 -122.320
# 4092          1380.0      1938           0.0    98103  47.6927 -122.338
# 4231           850.0      1908           0.0    98102  47.6374 -122.324
# 6073          1120.0      1915        2010.0    98105  47.6604 -122.289
# 8537             0.0      1996           0.0    98144  47.5923 -122.301
# 16830          750.0      1915           0.0    98105  47.6684 -122.309
# 18428          940.0      1918           0.0    98105  47.6654 -122.307
#
#        sqft_living15  sqft_lot15
# 8748            1420        4960
# 13301           2730       10400
# 15147           2040       11914
# 19239           1810        3745
# 4092            1460        6291
# 4231            1960        2450
# 6073            2510        5000
# 8537            1448        3866
# 16830           2710        4320
# 18428           2460        4400

# %% [markdown]
# The other houses with 9+ bedrooms appear to just be large houses

# %% [markdown]
# **sqft_lot 1,651,359**

# %%
df_clean.nlargest(5, 'sqft_lot')
# Out:
#                id       date     price  bedrooms  bathrooms  sqft_living  \
# 1717   1020069017 2015-03-27  700000.0         4       1.00         1300
# 17305  3326079016 2015-05-04  190000.0         2       1.00          710
# 7640   2623069031 2014-05-21  542500.0         5       3.25         3010
# 7762   2323089009 2015-01-19  855000.0         4       3.50         4030
# 3945    722069232 2014-09-05  998000.0         4       3.25         3770
#
#        sqft_lot  floors  waterfront  view  condition  grade  sqft_above  \
# 1717    1651359     1.0         0.0   3.0          4      6        1300
# 17305   1164794     1.0         0.0   0.0          2      5         710
# 7640    1074218     1.5         0.0   0.0          5      8        2010
# 7762    1024068     2.0         0.0   0.0          3     10        4030
# 3945     982998     2.0         0.0   0.0          3     10        3770
#
#        sqft_basement  yr_built  yr_renovated  zipcode      lat     long  \
# 1717             0.0      1920           0.0    98022  47.2313 -122.023
# 17305            0.0      1915           0.0    98014  47.6888 -121.909
# 7640          1000.0      1931           0.0    98027  47.4564 -122.004
# 7762             0.0      2006           0.0    98045  47.4619 -121.744
# 3945             0.0      1992           0.0    98058  47.4140 -122.087
#
#        sqft_living15  sqft_lot15
# 1717            2560      425581
# 17305           1680       16730
# 7640            2450       68825
# 7762            1830       11700
# 3945            2290       37141

# %% [markdown]
# The property with a sqft_lot of 1,651,359, is an outlier, but isn't necessarily bad data.

# %% [markdown]
# **price 78,000**

# %%
df_clean.nsmallest(10, 'price')
# Out:
#                id       date    price  bedrooms  bathrooms  sqft_living  \
# 15279    40000362 2014-05-06  78000.0         2       1.00          780
# 465    8658300340 2014-05-23  80000.0         1       0.75          430
# 16184  3028200080 2015-03-24  81000.0         2       1.00          730
# 2139   1623049041 2014-05-08  82500.0         2       1.00          520
# 18453  7999600180 2014-05-29  83000.0         2       1.00          900
# 3763   1523049188 2015-04-30  84000.0         2       1.00          700
# 16700  1322049150 2015-03-05  85000.0         2       1.00          910
# 5860   9320900420 2014-10-14  89000.0         3       1.00          900
# 3106   1721801591 2015-02-19  89950.0         1       1.00          570
# 7985   2734100835 2015-03-03  90000.0         1       1.00          780
#
#        sqft_lot  floors  waterfront  view  condition  grade  sqft_above  \
# 15279     16344     1.0         0.0   0.0          1      5         780
# 465        5050     1.0         0.0   0.0          2      4         430
# 16184      9975     1.0         0.0   0.0          1      5         730
# 2139      22334     1.0         0.0   0.0          2      5         520
# 18453      8580     1.0         0.0   0.0          3      5         900
# 3763      20130     1.0         0.0   0.0          3      6         700
# 16700      9753     1.0         0.0   0.0          3      5         910
# 5860       4750     1.0         0.0   0.0          4      6         900
# 3106       4080     1.0         0.0   0.0          3      5         570
# 7985       4000     1.0         0.0   0.0          3      5         780
#
#        sqft_basement  yr_built  yr_renovated  zipcode      lat     long  \
# 15279            0.0      1942           0.0    98168  47.4739 -122.280
# 465              0.0      1912           0.0    98014  47.6499 -121.909
# 16184            0.0      1943           0.0    98168  47.4808 -122.315
# 2139             0.0      1951           0.0    98168  47.4799 -122.296
# 18453            0.0      1918           0.0    98168  47.4727 -122.270
# 3763             0.0      1949           0.0    98168  47.4752 -122.271
# 16700            0.0      1947           0.0    98032  47.3897 -122.236
# 5860             0.0      1969           0.0    98023  47.3026 -122.363
# 3106             0.0      1942           0.0    98146  47.5098 -122.334
# 7985             0.0      1905           0.0    98108  47.5424 -122.321
#
#        sqft_living15  sqft_lot15
# 15279           1700       10387
# 465             1200        7500
# 16184            860        9000
# 2139            1572       10570
# 18453           2060        6533
# 3763            1490       18630
# 16700           1160        7405
# 5860             900        3404
# 3106             890        5100
# 7985            1150        4000

# %% [markdown]
# not bad data, just the cheapest houses in the set

# %% [markdown]
# **bathrooms - 0.5**

# %%
df_clean[df_clean.bathrooms == 0.5]
# Out:
#                id       date     price  bedrooms  bathrooms  sqft_living  \
# 2259   3971701455 2014-10-03  273000.0         2        0.5         1180
# 10413  7129800036 2015-01-14  109000.0         2        0.5          580
# 11662  7987400316 2014-08-14  255000.0         1        0.5          880
# 12029  2991000160 2014-12-12  312500.0         4        0.5         2300
#
#        sqft_lot  floors  waterfront  view  condition  grade  sqft_above  \
# 2259       7750     1.0         0.0   0.0          4      6         590
# 10413      6900     1.0         0.0   0.0          3      5         580
# 11662      1642     1.0         0.0   0.0          3      6         500
# 12029      5570     2.0         0.0   0.0          3      8        2300
#
#        sqft_basement  yr_built  yr_renovated  zipcode      lat     long  \
# 2259           590.0      1945           0.0    98155  47.7690 -122.316
# 10413            0.0      1941           0.0    98118  47.5135 -122.262
# 11662          380.0      1910           0.0    98126  47.5732 -122.372
# 12029            0.0      1996           0.0    98092  47.3285 -122.168
#
#        sqft_living15  sqft_lot15
# 2259            1380        8976
# 10413           1570        5040
# 11662           1410        2992
# 12029           1820        6371

# %% [markdown]
# seems too odd for a house of its size and built in 1996 to only have 0.5 baths. It should be assumed to be bad data and dropped.

# %%
df_clean = df_clean.drop(df_clean[df_clean.id == 2991000160].index)

# %% [markdown]
# ## EDA of pre-processed data
#
# What features have the strongest influence on price?

# %% [markdown]
# ### Sale Dates

# %%
df_clean.date.describe()
# Out:
# count                   21418
# unique                    372
# top       2014-06-23 00:00:00
# freq                      142
# first     2014-05-02 00:00:00
# last      2015-05-27 00:00:00
# Name: date, dtype: object

# %%
df_clean.date.hist();
# Out:
# /Users/freethrall/anaconda3/envs/learn-env/lib/python3.6/site-packages/pandas/plotting/_matplotlib/converter.py:103: FutureWarning: Using an implicitly registered datetime converter for a matplotlib plotting method. The converter was registered by pandas on import. Future versions of pandas will require you to explicitly register matplotlib converters.
#
# To register the converters:
# 	>>> from pandas.plotting import register_matplotlib_converters
# 	>>> register_matplotlib_converters()
#   warnings.warn(msg, FutureWarning)

# %% [markdown]
# In the time frame of the house sales in the dataset, there are 391 days and there were sales on 372 of those days.
#
# Sales took a dip in early 2015.  The dataset is from King County in Washington state, so the cold weather probably depressed sales.
#
# Sales in 2015 don't look to be on the same trend as in 2014, to find out why it would be good to look at other economic data.

# %%
plt.scatter(df_clean.date, df_clean.price)

# %% [markdown]
#  date based upon day has no correlation to price

# %%
plt.scatter(df_clean.date.apply(lambda date: date.month), df_clean.price)

# %%
df_clean['sale_month'] = df_clean.date.apply(lambda date: date.month)

# %%
df_clean[['sale_month', 'price']].corr()
# Out:
#             sale_month     price
# sale_month    1.000000 -0.007868
# price        -0.007868  1.000000

# %% [markdown]
# date based upon month also has no correlation to price, but should be considered as a
# potential interaction with the waterfront properties.

# %% [markdown]
# ### price - the target

# %%
df_clean.price.hist()

# %% [markdown]
# It is very right skewed, the highest outliers may need to be dropped.

# %% [markdown]
# ### bedrooms

# %%
df_clean.bedrooms.describe()
# Out:
# count    21418.000000
# mean         3.372537
# std          0.903024
# min          1.000000
# 25%          3.000000
# 50%          3.000000
# 75%          4.000000
# max         11.000000
# Name: bedrooms, dtype: float64

# %%
df_clean.bedrooms.hist()

# %%
df_clean.bedrooms.value_counts()
# Out:
# 3     9731
# 4     6848
# 2     2736
# 5     1586
# 6      265
# 1      191
# 7       38
# 8       13
# 9        6
# 10       3
# 11       1
# Name: bedrooms, dtype: int64

# %%
df_clean.bedrooms.value_counts(normalize=True)
# Out:
# 3     0.454337
# 4     0.319731
# 2     0.127743
# 5     0.074050
# 6     0.012373
# 1     0.008918
# 7     0.001774
# 8     0.000607
# 9     0.000280
# 10    0.000140
# 11    0.000047
# Name: bedrooms, dtype: float64

# %% [markdown]
# properties with less that one percent of the data may be candidates for dropping for being outliers,
# even though this column will be treated as continuous data.

# %%
df_clean[['bedrooms', 'price']].corr()
# Out:
#           bedrooms     price
# bedrooms  1.000000  0.316944
# price     0.316944  1.000000

# %% [markdown]
# The number of bedrooms has a low correlation to price.  That seems a little counter intuitive, because
# people want enough bedrooms for their family and more bedrooms should demand a higher price, but potentially
# number of bedrooms alone isn't strongly correlated.  Perhaps it's the size of the bedrooms too, and or their relation to other factors.  This should be investigated as a possible candidate for an interaction.

# %% [markdown]
# ### bathrooms

# %%
df_clean.bathrooms.describe()
# Out:
# count    21418.000000
# mean         2.118522
# std          0.768672
# min          0.500000
# 25%          1.750000
# 50%          2.250000
# 75%          2.500000
# max          8.000000
# Name: bathrooms, dtype: float64

# %%
df_clean.bathrooms.hist()

# %%
df_clean.bathrooms.value_counts()
# Out:
# 2.50    5352
# 1.00    3794
# 1.75    3019
# 2.25    2031
# 2.00    1913
# 1.50    1429
# 2.75    1182
# 3.00     747
# 3.50     729
# 3.25     586
# 3.75     155
# 4.00     134
# 4.50      99
# 4.25      79
# 0.75      70
# 4.75      23
# 5.00      21
# 5.25      13
# 5.50      10
# 1.25       9
# 6.00       6
# 5.75       4
# 0.50       3
# 8.00       2
# 6.25       2
# 6.75       2
# 6.50       2
# 7.50       1
# 7.75       1
# Name: bathrooms, dtype: int64

# %%
df_clean.bathrooms.value_counts(normalize=True)
# Out:
# 2.50    0.249883
# 1.00    0.177141
# 1.75    0.140956
# 2.25    0.094827
# 2.00    0.089317
# 1.50    0.066720
# 2.75    0.055187
# 3.00    0.034877
# 3.50    0.034037
# 3.25    0.027360
# 3.75    0.007237
# 4.00    0.006256
# 4.50    0.004622
# 4.25    0.003688
# 0.75    0.003268
# 4.75    0.001074
# 5.00    0.000980
# 5.25    0.000607
# 5.50    0.000467
# 1.25    0.000420
# 6.00    0.000280
# 5.75    0.000187
# 0.50    0.000140
# 8.00    0.000093
# 6.25    0.000093
# 6.75    0.000093
# 6.50    0.000093
# 7.50    0.000047
# 7.75    0.000047
# Name: bathrooms, dtype: float64

# %%
df_clean[['bathrooms', 'price']].corr()
# Out:
#            bathrooms     price
# bathrooms   1.000000  0.525223
# price       0.525223  1.000000

# %% [markdown]
# bathrooms has a decent correlation with price.  people want sufficient bathrooms, and with the greatest percentage being in the interval 2 <= bathroom  < 3, that must be the most popular number of bathrooms for this set of properties.  It should be considered for an interaction with bedrooms and potentially others.

# %% [markdown]
# ### sqft_living

# %%
df_clean.sqft_living.describe()
# Out:
# count    21418.000000
# mean      2083.144131
# std        918.844667
# min        370.000000
# 25%       1430.000000
# 50%       1920.000000
# 75%       2550.000000
# max      13540.000000
# Name: sqft_living, dtype: float64

# %%
df_clean.sqft_living.hist()

# %%
plt.scatter(df_clean.sqft_living, df_clean.price)

# %%
df_clean[['sqft_living', 'price']].corr()
# Out:
#              sqft_living     price
# sqft_living     1.000000  0.701321
# price           0.701321  1.000000

# %% [markdown]
# sqft_living is highly correlated with price.  The outlier value with the highest sqft_living value, but an out of line sale price should be considered for dropping.

# %% [markdown]
# ### sqft_lot

# %%
df_clean.sqft_lot.describe()
# Out:
# count    2.141800e+04
# mean     1.512891e+04
# std      4.153264e+04
# min      5.200000e+02
# 25%      5.040000e+03
# 50%      7.614500e+03
# 75%      1.069350e+04
# max      1.651359e+06
# Name: sqft_lot, dtype: float64

# %%
df_clean.sqft_lot.hist()

# %%
plt.scatter(df_clean.sqft_lot, df_clean.price)

# %%
df_clean[['sqft_lot', 'price']].corr()
# Out:
#           sqft_lot     price
# sqft_lot  1.000000  0.088786
# price     0.088786  1.000000

# %% [markdown]
# sqft_lot is not correlated with price, but maybe has an interaction.  All the highest priced properties
# have small lots, while the lowest priced properties have the largest lots, but most of the properties have a lower price and lower lot size.

# %% [markdown]
# ### floors

# %%
df_clean.floors.describe()
# Out:
# count    21418.000000
# mean         1.495985
# std          0.540085
# min          1.000000
# 25%          1.000000
# 50%          1.500000
# 75%          2.000000
# max          3.500000
# Name: floors, dtype: float64

# %%
df_clean.floors.value_counts()
# Out:
# 1.0    10551
# 2.0     8202
# 1.5     1888
# 3.0      609
# 2.5      161
# 3.5        7
# Name: floors, dtype: int64

# %%
df_clean.sqft_lot.hist()

# %%
plt.scatter(df_clean.floors, df_clean.price)

# %%
df_clean[['floors', 'price']].corr()
# Out:
#           floors     price
# floors  1.000000  0.255023
# price   0.255023  1.000000

# %% [markdown]
# floors has low correlation with price, has potential as an interacting feature. Also, the house
# being a 'split level' may offer additional information as an interacting feature, as well as marking a house with 3+ floors as 'something else'

# %% [markdown]
# ### waterfront

# %%
df_clean.waterfront.value_counts()
# Out:
# 0.0    21272
# 1.0      146
# Name: waterfront, dtype: int64

# %%
df_clean.waterfront.value_counts(normalize=True)
# Out:
# 0.0    0.993183
# 1.0    0.006817
# Name: waterfront, dtype: float64

# %%
plt.scatter(df_clean.waterfront, df_clean.price)

# %%
df_clean[['waterfront', 'price']].corr()
# Out:
#             waterfront     price
# waterfront    1.000000  0.264916
# price         0.264916  1.000000

# %% [markdown]
# waterfront has a low correlation with price.

# %% [markdown]
# ### view

# %%
df_clean.view.value_counts()
# Out:
# 0.0    19314
# 2.0      956
# 3.0      505
# 1.0      329
# 4.0      314
# Name: view, dtype: int64

# %%
df_clean.view.value_counts(normalize=True)
# Out:
# 0.0    0.901765
# 2.0    0.044635
# 3.0    0.023578
# 1.0    0.015361
# 4.0    0.014661
# Name: view, dtype: float64

# %%
plt.scatter(df_clean.view, df_clean.price)

# %%
df_clean[['view', 'price']].corr()
# Out:
#            view     price
# view   1.000000  0.392788
# price  0.392788  1.000000

# %% [markdown]
# view has low correlation with price.

# %% [markdown]
# ### condition

# %%
df_clean.condition.value_counts()
# Out:
# 3    13899
# 4     5643
# 5     1686
# 2      162
# 1       28
# Name: condition, dtype: int64

# %%
df_clean.condition.value_counts(normalize=True)
# Out:
# 3    0.648940
# 4    0.263470
# 5    0.078719
# 2    0.007564
# 1    0.001307
# Name: condition, dtype: float64

# %%
plt.scatter(df_clean.condition, df_clean.price)

# %%
df_clean[['condition', 'price']].corr()
# Out:
#            condition     price
# condition   1.000000  0.034176
# price       0.034176  1.000000

# %% [markdown]
# condition has no correlation with price

# %% [markdown]
# ### grade

# %%
df_clean.grade.value_counts()
# Out:
# 7     8888
# 8     6040
# 9     2606
# 6     1995
# 10    1130
# 11     396
# 5      234
# 12      88
# 4       27
# 13      13
# 3        1
# Name: grade, dtype: int64

# %%
df_clean.grade.value_counts(normalize=True)
# Out:
# 7     0.414978
# 8     0.282006
# 9     0.121673
# 6     0.093146
# 10    0.052759
# 11    0.018489
# 5     0.010925
# 12    0.004109
# 4     0.001261
# 13    0.000607
# 3     0.000047
# Name: grade, dtype: float64

# %%
plt.scatter(df_clean.grade, df_clean.price)

# %%
df_clean[['grade', 'price']].corr()
# Out:
#           grade     price
# grade  1.000000  0.666864
# price  0.666864  1.000000

# %% [markdown]
# grade is highly correlated with price and visually looks like a candidate for a polynomial.

# %% [markdown]
# ### sqft_above

# %%
df_clean.sqft_above.describe()
# Out:
# count    21418.000000
# mean      1791.181530
# std        828.708467
# min        370.000000
# 25%       1200.000000
# 50%       1560.000000
# 75%       2220.000000
# max       9410.000000
# Name: sqft_above, dtype: float64

# %%
df_clean.sqft_above.hist()

# %%
plt.scatter(df_clean.sqft_above, df_clean.price)

# %%
df_clean[['sqft_above', 'price']].corr()
# Out:
#             sqft_above     price
# sqft_above    1.000000  0.604477
# price         0.604477  1.000000

# %% [markdown]
# Has a high correlation with price

# %% [markdown]
# ### sqft_basement

# %%
df_clean.sqft_basement.describe()
# Out:
# count    21418.000000
# mean       285.936642
# std        440.024581
# min          0.000000
# 25%          0.000000
# 50%          0.000000
# 75%        550.000000
# max       4820.000000
# Name: sqft_basement, dtype: float64

# %%
df_clean.sqft_basement.hist()

# %%
plt.scatter(df_clean.sqft_basement, df_clean.price)

# %%
df_clean[['sqft_basement', 'price']].corr()
# Out:
#                sqft_basement     price
# sqft_basement       1.000000  0.321247
# price               0.321247  1.000000

# %% [markdown]
# most properties do not have a basement, but for those that do, there is a low correlation with price.

# %% [markdown]
# ### yr_built

# %%
df_clean.yr_built.describe()
# Out:
# count    21418.000000
# mean      1971.092959
# std         29.387559
# min       1900.000000
# 25%       1952.000000
# 50%       1975.000000
# 75%       1997.000000
# max       2015.000000
# Name: yr_built, dtype: float64

# %%
df_clean.yr_built.hist(bins='auto')

# %%
df_clean[['yr_built', 'price']].corr()
# Out:
#           yr_built     price
# yr_built  1.000000  0.051049
# price     0.051049  1.000000

# %% [markdown]
# as would be expected, yr_built has no numerical correlation with price, it has
# potential as categorical data

# %% [markdown]
# ### yr_renovated

# %%
df_clean.yr_renovated.describe()
# Out:
# count    21418.000000
# mean        68.963162
# std        364.568710
# min          0.000000
# 25%          0.000000
# 50%          0.000000
# 75%          0.000000
# max       2015.000000
# Name: yr_renovated, dtype: float64

# %%
df_clean.yr_renovated.hist(bins='auto')

# %%
df_clean[df_clean.yr_renovated != 0].yr_renovated.hist(bins='auto')

# %% [markdown]
# most houses have not had a renovation, but of those that have, it's been a recent one.  Potentially
# a binary feature for renovation, and a new year feature having the most recent value of yr_built and yr_renovated.  The binary feature may be an interacting term as well.

# %% [markdown]
# ### zipcode

# %%
df_clean.zipcode.describe()
# Out:
# count    21418.000000
# mean     98077.872537
# std         53.479614
# min      98001.000000
# 25%      98033.000000
# 50%      98065.000000
# 75%      98117.000000
# max      98199.000000
# Name: zipcode, dtype: float64

# %%
df_clean.zipcode.hist()

# %%
df_clean[['zipcode', 'price']].corr()
# Out:
#           zipcode     price
# zipcode  1.000000 -0.051168
# price   -0.051168  1.000000

# %% [markdown]
# Zipcode should be considered a category. Other data can be able to be learned about each category that may be usefull. ie. mean price, num sales, highest price, lowest price.

# %%
zip_data_list = []
for zipcode in df_clean.zipcode.unique():
    zip_data = {'zipcode': zipcode,
               'mean_price': round(df_clean[df_clean.zipcode == zipcode].price.mean(), 2),
               'num_sales': len(df_clean[df_clean.zipcode == zipcode]),
               'highest_price': round(df_clean[df_clean.zipcode == zipcode].price.max(), 2),
               'lowest_price': round(df_clean[df_clean.zipcode == zipcode].price.min(), 2)}
    zip_data_list.append(zip_data)

# %%
zip_data_df = pd.DataFrame(zip_data_list, columns=zip_data_list[0].keys())

# %%
zip_data_df
# Out:
#     zipcode  mean_price  num_sales  highest_price  lowest_price
# 0     98178   312850.94        258      1700000.0      100000.0
# 1     98125   472218.57        402      2050000.0      175000.0
# 2     98028   462426.77        282      1600000.0      160000.0
# 3     98136   551768.52        263      2230000.0      200000.0
# 4     98074   689562.75        435      3080000.0      280000.0
# ..      ...         ...        ...            ...           ...
# 65    98072   570698.79        272      1570000.0      200000.0
# 66    98188   290034.48        135       707000.0      110000.0
# 67    98014   455715.63        123      1680000.0       80000.0
# 68    98055   307650.94        260       631000.0      100000.0
# 69    98039  2187551.02         49      6890000.0      787500.0
#
# [70 rows x 5 columns]

# %%
for col in zip_data_df.columns[1:]:
    print(col)
    display(zip_data_df.nlargest(5, col))
# Out:
# mean_price
#     zipcode  mean_price  num_sales  highest_price  lowest_price
# 69    98039  2187551.02         49      6890000.0      787500.0
# 39    98004  1355971.76        315      7060000.0      425000.0
# 18    98040  1194873.64        282      5300000.0      500000.0
# 22    98112  1096933.93        268      3400000.0      169317.0
# 49    98102   899607.67        104      7700000.0      330000.0
# num_sales
#     zipcode  mean_price  num_sales  highest_price  lowest_price
# 15    98103   584998.94        599      1700000.0      238000.0
# 9     98038   367554.41        586      1350000.0      110000.0
# 11    98115   621708.31        576      2300000.0      200000.0
# 23    98052   646339.66        571      2200000.0      270000.0
# 25    98117   578576.00        548      1370000.0      125000.0
# highest_price
#     zipcode  mean_price  num_sales  highest_price  lowest_price
# 49    98102   899607.67        104      7700000.0      330000.0
# 39    98004  1355971.76        315      7060000.0      425000.0
# 69    98039  2187551.02         49      6890000.0      787500.0
# 18    98040  1194873.64        282      5300000.0      500000.0
# 59    98033   804063.88        431      5110000.0      130000.0
# lowest_price
#     zipcode  mean_price  num_sales  highest_price  lowest_price
# 69    98039  2187551.02         49      6890000.0      787500.0
# 18    98040  1194873.64        282      5300000.0      500000.0
# 39    98004  1355971.76        315      7060000.0      425000.0
# 42    98075   791602.68        358      3200000.0      406430.0
# 40    98005   810289.70        168      1960000.0      400000.0

# %%
for col in zip_data_df.columns[1:]:
    print(col)
    display(zip_data_df.nsmallest(5, col))
# Out:
# mean_price
#     zipcode  mean_price  num_sales  highest_price  lowest_price
# 16    98002   234606.72        197       389000.0       95000.0
# 52    98168   242447.75        264       600000.0       78000.0
# 47    98032   253317.32        123       545000.0       85000.0
# 27    98001   282268.85        358       850000.0      100000.0
# 32    98148   288112.32         56       600600.0      122000.0
# num_sales
#     zipcode  mean_price  num_sales  highest_price  lowest_price
# 69    98039  2187551.02         49      6890000.0      787500.0
# 32    98148   288112.32         56       600600.0      122000.0
# 61    98024   590059.11         79      1860000.0      200000.0
# 44    98010   420470.70         99       935000.0      135000.0
# 49    98102   899607.67        104      7700000.0      330000.0
# highest_price
#     zipcode  mean_price  num_sales  highest_price  lowest_price
# 16    98002   234606.72        197       389000.0       95000.0
# 47    98032   253317.32        123       545000.0       85000.0
# 20    98030   297939.22        253       565000.0      139000.0
# 52    98168   242447.75        264       600000.0       78000.0
# 32    98148   288112.32         56       600600.0      122000.0
# lowest_price
#     zipcode  mean_price  num_sales  highest_price  lowest_price
# 52    98168   242447.75        264       600000.0       78000.0
# 67    98014   455715.63        123      1680000.0       80000.0
# 47    98032   253317.32        123       545000.0       85000.0
# 30    98023   288448.60        492      1280000.0       89000.0
# 8     98146   363846.35        281      1410000.0       89950.0

# %% [markdown]
# #### heatmaps

# %%
gmaps.configure(api_key=os.environ["GOOGLE_API_KEY"])

# %%
Lon = np.linspace(df_clean.long.min(), df_clean.long.max(), 100) 
Lat = np.linspace(df_clean.lat.min(), df_clean.lat.max(), 100) 

lat_increment = abs(Lat[1] - Lat[0])
long_increment = abs(Lon[1] - Lon[0])

# %% [markdown]
# **A heatmap of property sale activity**

# %%
house_counts = np.zeros((100,100)) 

for house in range(len(df_clean)):
    i0 = int(abs(df_clean['lat'].values[house] - df_clean['lat'].min()) // lat_increment)
    i1 = int(abs(df_clean['long'].values[house] - df_clean['long'].min()) // long_increment)
    house_counts[i0, i1] += 1
    
longitude_values = [Lon,]*100 
latitude_values = np.repeat(Lat,100) 

house_counts.resize((10000,)) 

heatmap_data = {'Counts': house_counts, 
                'latitude': latitude_values, 
                'longitude' : np.concatenate(longitude_values)}

# %%
df_map = pd.DataFrame(data=heatmap_data)

# %%
locations = df_map[['latitude', 'longitude']] 
weights = df_map['Counts'] 
fig = gmaps.figure() 
heatmap_layer = gmaps.heatmap_layer(locations, weights=weights) 
fig.add_layer(heatmap_layer) 
fig
# Out:
# Figure(layout=FigureLayout(height='420px'))

# %% [markdown]
# **A heatmap of total sales per sector**

# %%
house_price_sums = np.zeros((100,100)) 

for house in range(len(df_clean)):
    i0 = int(abs(df_clean['lat'].values[house] - df_clean['lat'].min()) // lat_increment)
    i1 = int(abs(df_clean['long'].values[house] - df_clean['long'].min()) // long_increment)
    house_price_sums[i0, i1] += df_clean['price'].values[house]

# %%
house_price_sums.resize((10000,))

# %%
prices_heatmap_data = {'Counts': house_price_sums, 
                'latitude': latitude_values, 
                'longitude' : np.concatenate(longitude_values)} 
df_prices_map = pd.DataFrame(data=prices_heatmap_data)

# %%
# counties_geojason = gmaps.geojson_geometries.load_geometry('us-counties')
# geojson_layer = gmaps.geojson_layer(counties_geojason, fill_opacity=0)

# %%
with open('cleaned_washington_geodata.json') as f:
    geometry = json.load(f)
zipcodes_layer = gmaps.geojson_layer(geometry, fill_opacity=0)

# %%
with open('us-county-boundaries.geojson') as f:
    geometry = json.load(f)
county_layer = gmaps.geojson_layer(geometry, fill_opacity=0.1)

# %%
locations = df_prices_map[['latitude', 'longitude']] 
weights = df_prices_map['Counts'] 
fig = gmaps.figure(center=(47.6092,-122.3363), zoom_level=10)

# zipcode markers
zip_98103 = gmaps.Marker((47.671, -122.342), info_box_content='98103 Seattle')
zip_98038 = gmaps.Marker((47.382, -122.036), info_box_content='98038 Maple Valley')
zip_98115 = gmaps.Marker((47.684, -122.301), info_box_content='98115 Seattle')
zip_markers = gmaps.drawing_layer(features=[zip_98103, zip_98038, zip_98115], show_controls=False)

fig.add_layer(zip_markers)
# fig.add_layer(geojson_layer)
fig.add_layer(zipcodes_layer)
fig.add_layer(county_layer)
fig.add_layer(gmaps.heatmap_layer(locations, weights=weights)) 
fig
# Out:
# Figure(layout=FigureLayout(height='420px'))

# %% [markdown]
# There is a lot of price and activity variety relating to zipcodes; they should definately be a categorical feature.
#
# The sales volume and the gross sales are all in the western portion of the county centered around the major cities of Seattle, Redmond, Bellevue and Kirkland.
#
# Because zipcode do not have a uniform size, the sales volume directly isn't very informative, although it does have some correlation to the total value of sales in a zip code.
#
# Proximity to one of these major cities maybe a significant feature relating to lat/long.

# %% [markdown]
# #### lat long

# %%
df_clean.lat.describe()
# Out:
# count    21418.000000
# mean        47.560202
# std          0.138584
# min         47.155900
# 25%         47.471225
# 50%         47.572100
# 75%         47.678075
# max         47.777600
# Name: lat, dtype: float64

# %%
df_clean.long.describe()
# Out:
# count    21418.000000
# mean      -122.213780
# std          0.140794
# min       -122.519000
# 25%       -122.328000
# 50%       -122.230000
# 75%       -122.125000
# max       -121.315000
# Name: long, dtype: float64

# %%
locations = df_prices_map[['latitude', 'longitude']] 
weights = df_prices_map['Counts'] 
fig = gmaps.figure(center=(47.6092,-122.3363), zoom_level=10)

# lat long lines

lat_47_1 = gmaps.Line(start=(47.1559, -121.315000),
                     end=(47.1559, -122.519000),
                     stroke_weight=3.0)
lat_47_5 = gmaps.Line(start=(47.572100, -121.315000),
                     end=(47.572100, -122.519000),
                     stroke_weight=3.0)
lat_47_7 = gmaps.Line(start=(47.777600, -121.315000),
                     end=(47.777600, -122.519000),
                     stroke_weight=3.0)
long_122_5 = gmaps.Line(start=(47.1559, -122.519000),
                     end=(47.777600, -122.519000),
                     stroke_weight=3.0)
long_122_2 = gmaps.Line(start=(47.1559, -122.230000),
                     end=(47.777600, -122.230000),
                     stroke_weight=3.0)
long_121_3 = gmaps.Line(start=(47.1559, -121.315000),
                     end=(47.777600, -121.315000),
                     stroke_weight=3.0)
lines_layer = gmaps.drawing_layer(features=[lat_47_1,lat_47_5, lat_47_7,
                                            long_122_5, long_122_2, long_121_3],
                                  show_controls=False)

fig.add_layer(lines_layer)
fig.add_layer(geojson_layer)
fig.add_layer(zipcodes_layer)
fig.add_layer(gmaps.heatmap_layer(locations, weights=weights)) 
fig
# Out:
# Figure(layout=FigureLayout(height='420px'))
